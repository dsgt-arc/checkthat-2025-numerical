# %%
# Get the queries decomposed
# This is the dataset that we will be actually using - one claim gets split into several (using ClaimDecomp) and then it comes with a top-1 evidence for each
import json
from rank_bm25 import BM25Okapi
import re
import dateparser
from joblib import Parallel, delayed
from multiprocessing import Manager
import numpy as np

import utils

# %% [markdown]
# # Load an inspect the datasets

# %% [markdown]
# Full corpus

# %%
#  https://drive.google.com/drive/folders/1GYzSK0oU2MiaKbyBO3hE8kO4gdmxDjCv
with open("../../data/corpus_evidence_unified.json") as f:
  corpus = json.load(f)

# %% [markdown]
# Supposed (wrong) bm25_top_100_claimdecomp.json

# %%
with open("../../data/bm25_top_100_claimdecomp.json") as f:
  bm25_top_100_claimdecomp = json.load(f)

# %%
print('number of scores doc 1:{}'.format(len(bm25_top_100_claimdecomp[0]['scores'])))
print('number of doc_Id doc 1:{}'.format(len(bm25_top_100_claimdecomp[0]['doc_id'])))
# Out:
# number of scores doc 1:300
# number of doc_Id doc 1:252

# %%
# Bm25 evidence files content - seems to be validation only

with open("../../data/English/bm25_evidence/val_claim_only_evidence_final.json") as f:
  bm25_evidence_val_claim_only = json.load(f)

# %%
len(bm25_evidence_val_claim_only) # as the name suggests, we do not have the train top 100 here.append
bm25_evidence_val_claim_only[0]['scores']

# %% [markdown]
# claim_to_bm25_evidence_mapping

# %%
with open("../../data/English/claim_to_bm25_evidence_mapping/train_claimonly_evidence_question_mapping.json") as f:
  train_claimonly_evidence_question_mapping = json.load(f)

# %%
# This is top 3 per original claim
train_claimonly_evidence_question_mapping
# Out:
# [{'claim': 'In her budget speech, Nirmala Sitharaman claimed that the Government distributed 35,000 crore LED bulbs in the country.',
#   'evidences': [{'questions': 'In her budget speech, Nirmala Sitharaman claimed that the Government distributed 35,000 crore LED bulbs in the country.',
#     'top_k_doc': ["conclusion: nirmala sitharaman didn't claim that govt distributed 35,000 crores led bulbs. from the video fo the speech it is clear that she said 35 crores. nirmala sitharaman didn't claim that govt distributed 35,000 crores led bulbs. from the video of the speech, it is clear that she said 35 crores, not 35000 crores.",
#      'jul 5, 2019  approximately 35 crore led bulbs have been distributed under ujala yojana leading to cost saving of 18,341 crores annually.66 pages',
#      '5 gen 2022  the power ministry has distributed 36.78 crore led lights under the ujala programme in seven years, which saved 47778 million units of ...']}],
#   'label': 'False'},
#  {'claim': 'Florida residents affected by Hurricane Irma can receive $197 in food stamp benefits, but only if they can show that their homes lost power for more than two hours.',
#   'evidences': [{'questions': 'Florida residents affected by Hurricane Irma can receive $197 in food stamp benefits, but only if they can show that their homes lost power for more than two hours.',
#     'top_k_doc': ["18 sept. 2017  (wsvn) - a few rumors are circulating that anyone who lost power during hurricane irma can get food stamps, but that's not exactly true.",
#      'oct 11, 2017  south floridians who lost food, income or property during hurricane irma may be eligible for special cards worth hundreds of dollars to ...',
#      "13 sept. 2017  available for florida residents impacted by hurricane irma. fema's tsa program assistance will provide a short-term jump-start for migrants ...201 pages"]}],
#   'label': 'False'},
#  {'claim': "Bill Gates' foundation tested a polio vaccine in India that left at least 490,000 children paralyzed",
#   'evidences': [{'questions': "Bill Gates' foundation tested a polio vaccine in India that left at least 490,000 children paralyzed",
#     'top_k_doc': ['490,000 children paralyzed. "bill gates foundation tested a polio vax ... gates foundation had tested polio vaccine in india between 2000 & 2017 and had paralysed',
#      'in spring, facebook posts shared tens of thousands of times falsely claimed that a polio vaccine tested by the bill and melinda gates foundation paralysed 490,000 children in india.',
#      'jun 6, 2020  they include claims that the bill and melinda gates foundation has tested vaccines on children in africa and india, leading to thousands of ...']}],
#   'label': 'False'},
#  {'claim': 'SaysHillary Clinton "took 13 hours to send help to Americans under fire" during the terrorist attack in Benghazi.',
#   'evidences': [{'questions': 'SaysHillary Clinton "took 13 hours to send help to Americans under fire" during the terrorist attack in Benghazi.',
#     'top_k_doc': ['23 ott 2015  hillary clinton endures an 11-hour hearing before a us congress committee over the deadly 2012 attacks in benghazi, libya, when she was ...',
#      '2015-10-21  former secretary of state hillary clinton testifies before a house committee on the events surrounding the 2012 terrorist attacks in benghazi, ...',
#      "16 ott 2012  us secretary of state hillary clinton took the blame monday for last month's deadly attack on the us diplomatic mission in benghazi, ..."]}],
#   'label': 'False'},
#  {'claim': '"Send your postcards to 5 key states to decertify fraud” in the 2020 election.',
#   'evidences': [{'questions': '"Send your postcards to 5 key states to decertify fraud” in the 2020 election.',
#     'top_k_doc': ['2021-03-15  this included efforts to send threatening e-mails to american citizens and to amplify concerns about voter fraud in the election.  in a ...',
#      '1 fvr. 2022  ... election in their states, based on false claims of widespread voter fraud. in a memo sent to vos on nov. 16, 2020, an attorney from ...',
#      '1 aot 2023  that there had been outcome-determinative fraud in the 2020 presidential election. ... instead be used in a number of states as fraudulent ...']}],
#   'label': 'False'},
#  {'claim': 'Under HR 1, a person can still vote if they are 16, in the U.S. illegally, have no ID and have not registered to vote',
#   'evidences': [{'questions': 'Under HR 1, a person can still vote if they are 16, in the U.S. illegally, have no ID and have not registered to vote',
#     'top_k_doc': ['members of the military who are not registered to vote, may apply in person and vote at the county election office.',
#      '17 aot 2023  all registered voters can request a no-excuse vote-by-mail ballot, or you can vote early in person to avoid lines on election day.',
#      'it establishes that all californians turning 17 can register to vote. voter pre-registration measures allowing 16-year-olds to pre-register have also become law ...']}],
#   'label': 'Half True/False'},
#  {'claim': 'Violence video shows rival groups fighting at 2022 football tournament in Democratic Republic of Congo, not March 2023 protests in Kenya',
#   'evidences': [{'questions': 'Violence video shows rival groups fighting at 2022 football tournament in Democratic Republic of Congo, not March 2023 protests in Kenya',
#     'top_k_doc': ['violent video shows rival groups fighting at 2022 football tournament in democratic republic of congo, not march 2023 protests in kenya.',
#      'violent video shows rival groups fighting at 2022 football tournament in democratic republic of congo, not march 2023 protests in kenya. march 30, 2023. 0.',
#      "8 ago 2023  in march 2023, kenya's opposition leader raila odinga called for demonstrations ... the article explains the factors behind this violence and some ..."]}],
#   'label': 'False'},
#  {'claim': 'In Virginia, "people are going and getting marriage licenses who are 12 and 13, and 14 and 15 years old."',
#   'evidences': [{'questions': 'In Virginia, "people are going and getting marriage licenses who are 12 and 13, and 14 and 15 years old."',
#     'top_k_doc': ['virginia code of domestic relations, title 20: where to obtain a license: a marriage license in virginia is issued by the clerk or his/her deputy clerk of a circuit court in any county or city in the commonwealth of virginia: age requirements: be at least 16 years old with parent or guardian permission.',
#      'virginia marriage license requirements. in virginia, you need to be at least 18 years old in order to apply for a marriage license. while many ...',
#      'only three states, not including virginia, have no statutory minimum age for marriage licenses. ... in virginia, when a person turns eighteen years of age, they ...']}],
#   'label': 'True'},
#  {'claim': '“scientists find virus contains tiny chunk of DNA that matches sequence patented by Moderna THREE YEARS before pandemic began”',
#   'evidences': [{'questions': '“scientists find virus contains tiny chunk of DNA that matches sequence patented by Moderna THREE YEARS before pandemic began”',
#     'top_k_doc': ['now scientists find virus contains tiny chunk of dna that matches sequence patented by moderna three years before pandemic began. dan het',
#      'man-made covid virus: scientists find virus contains tiny chunk of dna that matches sequence patented by moderna three years before pandemic began',
#      "23 fvr. 2022  scientists claim covid virus contains tiny chunk of dna that 'matches sequence patented by moderna three years before pandemic began'. by ..."]}],
#   'label': 'False'},
#  {'claim': 'Minnesota expected to get 16 inches of snowfall within the next week!',
#   'evidences': [{'questions': 'Minnesota expected to get 16 inches of snowfall within the next week!',
#     'top_k_doc': ['minnesota will see accumulating snowfall. however, the persistent low and will also get their killing frost by the first half of next week. weather',
#      'new snow total predictions were down for wednesday night. by 9:30 p.m., the expected final totals ended on the lower end of what was deemed possible by the nws, said meteorologist mike griesinger. but parts of western minnesota were slated to get a walloping 15 or 16 inches overnight. the twin cities metro area was forecast to see a more modest 8 to 12 inches overnight, while northern minnesota was in line for 12 to 18 inches.',
#      'snowfall totals through thursday december 22, 2022 in minnesota. does not include additional snow falling in northeastern minnesota through the weekend. the ...']}],
#   'label': 'False'},
#  {'claim': '“In 2020, there was a 64% drop in cases of GBVF compared to the same period in 2019.”',
#   'evidences': [{'questions': '“In 2020, there was a 64% drop in cases of GBVF compared to the same period in 2019.”',
#     'top_k_doc': ['received, compared to 111 reports in 2018/2019 and 99 in 2019/2020. this means that ... number of gbvf cases cleared, and (ii) case management system upgraded.',
#      'di na john  2023  in uganda, 3280 cases of gbv were reported to police in april 2020 as compared to a monthly average of 1137 cases in 2019. clearly, government ...',
#      'number of gbvf cases cleared, and (ii) case report on the implementation of the south african national strategic plan on gbvf may 2020.']}],
#   'label': 'False'},
#  {'claim': '“President Obama and Vice President Biden never even tried to fix this (police reforms) during their eight-year period.”',
#   'evidences': [{'questions': '“President Obama and Vice President Biden never even tried to fix this (police reforms) during their eight-year period.”',
#     'top_k_doc': ["... biden and the obama state department's anti-corruption efforts. in fact, many ... vice president biden did not resolve this conflict of interest. instead, he ...",
#      'as vice president, joseph biden was the senior obama administration official overseeing anti-corruption efforts in ukraine. hence, any illegal activity ...',
#      'when his father was vice president and after he left office. for biden was vice president and the public face of the obama']}],
#   'label': 'False'},
#  {'claim': 'Ahead of Karnataka Assembly elections, Congress releases its manifesto that promises seven “Muslim-only” schemes.',
#   'evidences': [{'questions': 'Ahead of Karnataka Assembly elections, Congress releases its manifesto that promises seven “Muslim-only” schemes.',
#     'top_k_doc': ["the congress has promised seven 'muslim-only' schemes in its manifesto to woo the communitys voters ahead of telangana assembly elections 2018.",
#      "toi newswrap: congress promises seven 'muslim only' schemes in telangana manifesto | in its draft manifesto for telangana polls, congress",
#      "the draft has been accessed by times now. it shows that the congress has promised seven 'muslim-only' schemes in its manifesto to woo the communitys voters ahead of telangana assembly elections 2018."]}],
#   'label': 'False'},
#  {'claim': 'Bill Nelson "leased land that he owned for six cows, taking advantage of an agricultural tax loophole to dodge $43,000 in taxes just last year."',
#   'evidences': [{'questions': 'Bill Nelson "leased land that he owned for six cows, taking advantage of an agricultural tax loophole to dodge $43,000 in taxes just last year."',
#     'top_k_doc': ['10 ott 2012  "he leased land that he owned for six cows, taking advantage of an agricultural tax loophole to dodge $43,000 dollars in taxes last year ...',
#      '22.10.2012  he leased land that he owned for six cows, taking advantage of an agricultural tax loophole to dodge $43,000 in taxes just last year," says the ...',
#      '22 ott 2012  he leased land that he owned for six cows, taking advantage of an agricultural tax loophole to dodge $43,000 in taxes just last year," says ...']}],
#   'label': 'Half True/False'},
#  {'claim': 'The video shows G20 delegates having lunch with their hands',
#   'evidences': [{'questions': 'The video shows G20 delegates having lunch with their hands',
#     'top_k_doc': []}],
#   'label': 'False'},
#  {'claim': '"The city of Columbus would save $41 million a year if employees had to contribute to their own, guaranteed-check pensions."',
#   'evidences': [{'questions': '"The city of Columbus would save $41 million a year if employees had to contribute to their own, guaranteed-check pensions."',
#     'top_k_doc': ['an employee from the city of columbus, for which there is a pension contribution. high cost claims for medical and behavioral health (semi-',
#      "table a-3 presents the cost of each of the columbus consolidated government's five largest programs, as the city's annual pension cost was $13,241,739 for",
#      'as the city councils five-member subcommittee on pension sustainability found, there were plenty of reasons why the fund was in trouble, including a funding ratio of just 31 percent. over the years, providence had agreed to generous retirement benefits, including a relatively high cola of 6 percent, liberal disability increases and early retirement-age requirements. the city had also not been making its annual mandated payments into the pension. to crunch the numbers for pension reform, providence had used its longtime auditor, new yorkbased buck consultants, which testified to the city council subcommittee that suspending cola payments would produce the most savings. bucks calculation, however, assumed that the 2012 cola had not been paid; in fact, it had, and according to the suit that the city subsequently filed against the firm, because of bucks elemental error, the citys pension liabilities increased by $10 million over what was projected and relied upon when the city was negotiating modifications for the pension. buck has filed a countersuit alleging that providence was merely looking to get the best deal that it could regardless of bucks figures. the litigation is ongoing. but with the funding level still well below 35 percent, providences pension crisis is far from over. the same is true of many of the states other local pension plans, a number of which have taken steps similar to providences.']}],
#   'label': 'True'},
#  {'claim': 'Honeybees were not considered “endangered” in the U.S. as of September 2023.',
#   'evidences': [{'questions': 'Honeybees were not considered “endangered” in the U.S. as of September 2023.',
#     'top_k_doc': ['honeybees are not endangered, mainly because they are globally distributed and primarily managed by beekeepers. these important pollinators arent actually native to the united states; they were brought over from europe by colonizers in the 17th century to use for honey and beeswax. eventually, some of the managed bees escaped and formed wild honeybee colonies, but the majority of honeybees are still managed by humans.',
#      "oct 23, 2023  honeybees aren't endangered but have faced serious annual losses ... we have good data about the health of domestic honeybee populations, because ...",
#      '2023-03-13  hawaiian yellow-faced bees were listed as endangered. ... a report released in september 2021, the experts say the american bumblebee was "once a ...']}],
#   'label': 'True'},
#  {'claim': "The Domino's pizza chain is offering coupons for two free large pizzas to social media users who fill out an online survey.",
#   'evidences': [{'questions': "The Domino's pizza chain is offering coupons for two free large pizzas to social media users who fill out an online survey.",
#     'top_k_doc': ["9 apr 2020  the latest scam popping up on your newsfeed is a coupon for two free large pizzas from domino's.",
#      "domino's pizza chain is not offering coupons for two free large pizzas to social media users who fill out an online survey. its a scam to",
#      "sign in to earn points toward free pizza on this order! domino's pizza  home  order online  menu  coupons."]}],
#   'label': 'False'},
#  {'claim': 'Does This Video Show Moldova Residents Blocking A NATO Column In 2022?',
#   'evidences': [{'questions': 'Does This Video Show Moldova Residents Blocking A NATO Column In 2022?',
#     'top_k_doc': ['the news agency avia.pro obtained exclusive video footage showing how moldovan citizens blocked the movement of the nato military convoy, blocking the road and preventing the western military from advancing in the originally intended direction. citizens of moldova blocked the movement of a convoy of nato military equipment in the area of the settlement novi anenii. a column of military equipment was seen here against the background of mass protests expected on september 18 in moldova against the actions of the government - earlier, the movement of military equipment of the moldovan army was already recorded in a number of regions of moldova. judging by the video footage, we are talking about a convoy of at least 10 pieces of military equipment from nato countries. moreover, which is very remarkable, there are no identification marks on the latter. this only confirms the version that nato forces can really try to use to suppress protests against the moldovan authorities.',
#      'this stockpile worries moldovan officials and residents alike for the relations with the republic of moldova, nato, 27 october 2020; and united',
#      "24 ott 2023  moldova restricted tv broadcasts of russia-produced news, analytical and military-related content in june 2022 following moscow's invasion of ..."]}],
#   'label': 'False'},
#  {'claim': 'Photo shows Imran Khan supporter waving gun during rally in 2023',
#   'evidences': [{'questions': 'Photo shows Imran Khan supporter waving gun during rally in 2023',
#     'top_k_doc': ['nov 10, 2022  ... pistol and started shooting while khan waved at his supporters at the event last week. in the video address, khan rejected the police version.',
#      '28 oct. 2022  the growing crowd of khan supporters in lahore chanted slogans including imran ... khan has accused the military of supporting his opponents ...',
#      'videos show the chaotic aftermath of the former pakistani prime minister imran khan being shot at a political rally on thursday. khan can be seen emerging to rapturous chanting from his supporters. he seemed to be physically supported by aides. another video showed khan waving at the crowd before being taken to hospital.']}],
#   'label': 'Half True/False'},
#  {'claim': 'Hindu population has fallen by 19% in Assam and Muslim population increased by 21%',
#   'evidences': [{'questions': 'Hindu population has fallen by 19% in Assam and Muslim population increased by 21%',
#     'top_k_doc': ['assams hindu population will fall from 21.8 million to 21.2 million and will shrink further. assams hindu population also has a very low fertility rate. assams population grew only by about 11.6% in 2001-2011, whereas the muslim population grew by 26.2%, with muslims in many border districts growing by as high as 31%.',
#      '25 aot 2015  the proportion of hindu population to total population in 2011 has declined by 0.7 percentage ... hindus: 16.8%; muslim: 24.6%; christian: 15.5 ...',
#      'the hindu population in assam have increased from 2.78 million in 1901 to 19.18 million in 2011 census (a growth of 16.4 million in 110 years). hindus ...']}],
#   'label': 'False'},
#  {'claim': 'A patent for coronavirus was granted in 2018 to the Pirbright Institute UK, founded by Bill and Melinda Gates.',
#   'evidences': [{'questions': 'A patent for coronavirus was granted in 2018 to the Pirbright Institute UK, founded by Bill and Melinda Gates.',
#     'top_k_doc': ['the patent is for infectious bronchitis virus (a coronavirus of poultry) and bill and melinda. gates foundation did not fund the patent. the institute also...',
#      'the patent is for infectious bronchitis virus (a coronavirus of poultry) and bill and melinda. gates foundation did not fund the patent. the institute also ...',
#      '19 juin 2023  it does not hold a patent for the coronavirus. however, the pirbright institute has been granted patents related to specific strains of avian ...']}],
#   'label': 'False'},
#  {'claim': 'because the photo comes from a blog post published in September 2022.',
#   'evidences': [{'questions': 'because the photo comes from a blog post published in September 2022.',
#     'top_k_doc': ["mar 9, 2022  when it comes to photos and the internet, the mantra is if it looks too good to be true, then it probably isn't true."]}],
#   'label': 'False'},
#  {'claim': '"We\'ve got 7.2 percent unemployment (in Ohio), but when you include the folks who have stopped looking for work, it\'s actually over 10 percent."',
#   'evidences': [{'questions': '"We\'ve got 7.2 percent unemployment (in Ohio), but when you include the folks who have stopped looking for work, it\'s actually over 10 percent."',
#     'top_k_doc': ['the labor market is weak because if you count the unemployed, underemployed, and ... work, the unemployment rate "actually went up last month to 13.5 percent.',
#      "... people who have stopped looking for work because they can't find a job. is this true? yes and no. there are six unemployment rates calculated, and each one ...",
#      'heres a quick look are the places in ohio with the highest unemployment rate: there you have it folks, the ten cities with the lowest unemployment in the state of {state}. they have the numbers and jobs to back it up.']}],
#   'label': 'Half True/False'},
#  {'claim': '"Up [to] 20% of high school learners have tried to take their own lives."',
#   'evidences': [{'questions': '"Up [to] 20% of high school learners have tried to take their own lives."',
#     'top_k_doc': ['mar 15, 2022  nearly 20% of high school students report serious thoughts of suicide and 9% have made an attempt to take their lives, according to the ...',
#      'just 28% of people aged 20 or older have completed high school;']}],
#   'label': 'Half True/False'},
#  {'claim': 'A video that went viral in July 2023 authentically depicted an ad in Japan that read "Stop Zelenskyy, Stop War."',
#   'evidences': [{'questions': 'A video that went viral in July 2023 authentically depicted an ad in Japan that read "Stop Zelenskyy, Stop War."',
#     'top_k_doc': ['video was shot in october 2020, and the advertisement on the banner has nothing ... was the banner stop zelenskyy, stop war placed in japan? on july 31 and ...',
#      "2 ago 2023  is this an authentic ad in japan reading, 'stop zelenskyy, stop war'? 3 months ago. www.snopes.com  does this photo show a real giant among men ...",
#      '5 giorni fa  the video was shared with an array of claims, ranging from the dead ... for example, a video went viral in march 2022 allegedly showing ...']}],
#   'label': 'False'},
#  {'claim': 'Every illegal immigrant "can be eligible for up to $36,000 to $38,000 in earned income tax credits without paying a dime in."',
#   'evidences': [{'questions': 'Every illegal immigrant "can be eligible for up to $36,000 to $38,000 in earned income tax credits without paying a dime in."',
#     'top_k_doc': ["2015-10-01  indeed, the annual cost of free tax credits alone paid to illegal immigrants quadrupled to $4.2 billion in 2011. have 'free tax credits ...",
#      '... of whom are illegal immigrants, were paid $4.2 billion in refundable tax credits in 2010. any individual who earns income in the u.s., be it legally or ...',
#      'percent and 75 percent of unauthorized immigrants pay federal, state, and local taxes. illegal immigrants are estimated to pay in about $7 billion per year']}],
#   'label': 'False'},
#  {'claim': 'A scam is asking people to input the personal details, including bank details, to receive "Covid-19 Relieve."',
#   'evidences': [{'questions': 'A scam is asking people to input the personal details, including bank details, to receive "Covid-19 Relieve."',
#     'top_k_doc': ['it is a scam that asks people to input personal details, including bank details, to receive covid-19 relieve the fact it says relieve when it should say...',
#      'these scammers say they can get people financial help during the covid-19 pandemic, and then ask for money or personal information, like your social ...',
#      'citizens received scam emails soliciting personal information to receive the covid-19-relieve scam[108]. page 11. 11.  15 (34%) involved']}],
#   'label': 'True'},
#  {'claim': 'Confusion spreads online about 15,000 people detained in Iran',
#   'evidences': [{'questions': 'Confusion spreads online about 15,000 people detained in Iran',
#     'top_k_doc': ['fact check-confusion spreads online about 15,000 people detained in iran iran has detained two spanish nationals during anti-government protests  read more',
#      'in february, iran had acknowledged tens of thousands had been detained in the protests. mondays acknowledgment from ejehi offered an even higher than what activists had previously cited. however, theres been no mass release of prisoners documented in recent days by iranian media reports or activists. more than 19,700 people have been arrested during the protests, according to human rights activists in iran, a group thats been tracking the crackdown. at least 530 people have been killed as authorities violently suppressed demonstrations, the group said. iran has not offered a death toll for months. dubai, united arab emirates (ap)  iran announced monday that the countrys supreme leader has pardoned more than 22,000 people arrested in the recent anti-government protests that swept the islamic republic. there was no immediate independent confirmation of the mass release.',
#      '16 nov 2022  over 15,000 protesters have been detained by iranian authorities since unrest began in september. by reality check. bbc news. canadian prime ...']}],
#   'label': 'False'},
#  {'claim': '"For several days in July of 2012, Greenland surface ice cover melted more than at any time in 30 years of satellite observation. During that month, an estimated 97% of the ice sheet thawed."',
#   'evidences': [{'questions': '"For several days in July of 2012, Greenland surface ice cover melted more than at any time in 30 years of satellite observation. During that month, an estimated 97% of the ice sheet thawed."',
#     'top_k_doc': ["24 lug 2012  for days this month, greenland's surface ice cover melted over a larger area than at any time in more than 30 years of satellite ...",
#      "25 lug 2012  for several days this month, greenland's surface ice cover melted over a larger area than at any time in more than 30 years of satellite ...",
#      "washington  for several days this month, greenland's surface ice cover melted over a larger area than at any time in more than 30 years of satellite ..."]}],
#   'label': 'Half True/False'},
#  {'claim': '"Close to 40% of South Africans who need jobs are unemployed, meaning that more than nine million South Africans who need jobs and are capable of working cannot find employment."',
#   'evidences': [{'questions': '"Close to 40% of South Africans who need jobs are unemployed, meaning that more than nine million South Africans who need jobs and are capable of working cannot find employment."',
#     'top_k_doc': ["close to 40% of south africans who need jobs are unemployed, meaning that more than nine million south africans who need jobs and are capable of working cannot find employment. that's why...",
#      '9 nov 2020  millions of south africans who need jobs and are capable of working cannot find employment ... south africa has more than enough jobs but',
#      "mar 4, 2019  the eff's claim that more than 9 million  or close to 40%  of south africans who need jobs are unemployed is correct. almost 9.8 million ..."]}],
#   'label': 'True'},
#  {'claim': 'CLAIM:A new autopsy report for George Floyd has been released in 2023, revealing he died from a drug overdose,not from the actions of arresting Minneapolis police officers.',
#   'evidences': [{'questions': 'CLAIM:A new autopsy report for George Floyd has been released in 2023, revealing he died from a drug overdose,not from the actions of arresting Minneapolis police officers.',
#     'top_k_doc': ['1 giu 2020  the family of george floyd released the results of an independent autopsy monday afternoon that found his cause of death was homicide by ...',
#      "3 juin 2023  in this week's facts matter column, bob oswald explores claims that a recent autopsy shows george floyd did not die because of police abuse, ...",
#      'the hennepin county, minn. medical examiners office on wednesday evening released its complete 20-page autopsy report detailing the death of george floyd. the report was released the same day three former officers were accused by prosecutors of playing a role in floyds alleged murder. prosecutors also on wednesday upgraded charges against former officer derek chauvin, who now faces a new count of second-degree felony murder. chauvin had previously been charged with third-degree murder.']}],
#   'label': 'False'},
#  {'claim': 'Two pipeline workers were given fentanyl-laced water bottles in Chicago suburbs',
#   'evidences': [{'questions': 'Two pipeline workers were given fentanyl-laced water bottles in Chicago suburbs',
#     'top_k_doc': ['2023-07-26  the claim: two pipeline workers were given fentanyl-laced water bottles in chicago suburbs  our rating: false  company denied its workers were ...',
#      'a rumor that utility company workers drank from fentanyl-laced water bottles has spread in some parts of texas. one report sent via email',
#      'a national hoax claiming roadside workers were offered bottles in chicago, a facebook post purported to claim that two flaggers for a pipeline']}],
#   'label': 'False'},
#  {'claim': 'Warum in Berlin plötzlich 200.000 Ausländer mehr leben/n„Jeder vierte Berliner ist ein Ausländer” titelt die Berliner Zeitung „B.Z.”. Woher kommen 200.000 ausländische Neu-Berliner in nur einem Jahr?',
#   'evidences': [{'questions': 'Warum in Berlin plötzlich 200.000 Ausländer mehr leben/n„Jeder vierte Berliner ist ein Ausländer” titelt die Berliner Zeitung „B.Z.”. Woher kommen 200.000 ausländische Neu-Berliner in nur einem Jahr?',
#     'top_k_doc': ['von 2000 bis 2020 sind die bevlkerungszahlen in berlin leicht gestiegen. 2020 lebten etwa 3,66 millionen menschen in berlin. bei menschen deutscher staatsangehrigkeit berwiegt der frauenanteil leicht, bei menschen ohne deutsche staatsangehrigkeit ist es umgekehrt. bis auf das jahr 2020 ziehen tendenziell mehr menschen nach berlin, als aus berlin wegziehen  besonders deutlich war der unterschied in den jahren 2015 und 2016. fast 40 prozent der berlinerinnen und berliner sind verheiratet, etwa 43 prozent ledig und etwa 11 prozent geschieden.',
#      'am 27.04.2018 titelte die berliner morgenpost nach verffentlichung der ergebnisse der auslnderstatistik 2017: berlin vergisst 200 000 auslnder. die morgenpost beleuchtete in ihrem ausfhrlichen beitrag die hintergrnde. die aufregung seitens der nutzerinnen und nutzer der daten des amtes fr statistik (afs), insbesondere in der verwaltung, war gro. das afs erreichte vielfach die frage wie viele auslnder leben denn nun in berlin? und klrte ber die im umlauf befindlichen zahlen auf  denn verffentlicht wurde nicht nur eine auslnderzahl. am 31.12.2018 lebten 675 210 auslnderinnen und auslnder in der bundeshaupt-stadt. oder waren es vielleicht 748 472 oder doch 795 391? ein stichtag, drei zahlen, eine differenz von 120 000 personen  da ist konfusion vor- programmiert. die lsung ist allerdings vergleichsweise einfach, denn die voneinander differierenden zahlen gehen auf drei verschiedene quellen zurck: bevlkerungsfortschreibung, einwohnerregisterstatistik und auslnderstatistik. in berlin verliefen die ergebnisse der bevlkerungsfortschreibung und der einwohnerregisterstatistik von 1991 bis 2010 im groen und ganzen deckungsgleich. seit dem jahr 2011, dem jahr des zensus, weist die bevlkerungsfortschreibung eine um rund 75 000 geringere anzahl an personen auslndischer herkunft aus als die einwohnerregisterstatistik. die werte der auslnderstatistik sollten aufgrund ihres berichtskreises eigentlich leicht unterhalb der bevlkerungsfortschreibung liegen; in den 1990er jahren lagen die ergebnisse jedoch etwas hher. anfang der 2000er jahre wurden bereinigungen im auslnderzentralregister durchgefhrt, was einen starken rckgang der anzahl der dort registrierten auslnder zur folge hatte. 2017 kam es laut auslnderstatistik zu einem sprunghaften anstieg der auslnderzahl. die ursache liegt in den bereits genannten nachmeldungen. aufgrund der abmeldungen im folgejahr ging die zahl der auslnder dieser quelle nach entgegen dem trend im jahr 2018 in berlin sprbar zurck.',
#      'die einwohnerzahl in berlin hat einen neuen hchststand seit dem zweiten weltkrieg erreicht. das teilte das amt fr statistik berlin-brandenburg am dienstag mit. ende dezember 2022 hatten knapp 3,86 millionen brgerinnen und brger ihren hauptwohnsitz in berlin, hie es in einer mitteilung. das seien 75.329 menschen oder zwei prozent mehr als am vorjahresende. ein so groes plus von rund 75.000 menschen habe es seit der wiedervereinigung nicht mehr in berlin gegeben, hie es aus dem statistikamt. anmerkung der redaktion: in einer frheren version dieses artikels hie es: in berlin leben aktuell so viele menschen wie nie zuvor. tatschlich bezieht sich der vom amt fr statistik mitgeteilte einwohner-hchststand auf die zeit seit dem zweiten weltkrieg. der anteil der einwohnerinnen und einwohnern mit migrationshintergrund lag in berlin insgesamt 2022 bei 38,6 prozent. im bezirk mitte waren mehr als die hlfte (56,8 prozent) auslnder oder deutsche mit migrationshintergrund, in treptow-kpenick lag ihr anteil bei 22,3 prozent.']}],
#   'label': 'Half True/False'},
#  {'claim': 'Rudy Guliani was disbarred on June 24, 2021 — 35 years to the day after Roy Cohn was disbarred.',
#   'evidences': [{'questions': 'Rudy Guliani was disbarred on June 24, 2021 — 35 years to the day after Roy Cohn was disbarred.',
#     'top_k_doc': ['jun 25, 2021  rudy guliani was disbarred on june 24, 2021  35 years to the day after roy cohn was disbarred. ... before a judge. or if they dip into client ...',
#      "june 24, 2021. rachel maddow points out that donald trump's favorite lawyer, roy cohn, was disbarred 35 years to the day before rudy giuliani's law license ...",
#      "jun 24, 2021  rachel maddow points out that donald trump's favorite lawyer, roy cohn, was disbarred 35 years to the day before rudy giuliani's law license ..."]}],
#   'label': 'Half True/False'},
#  {'claim': 'Says Ellen Rosenblum "has said over and over again that this is a job where 80 percent of the job is being the government’s lawyer."',
#   'evidences': [{'questions': 'Says Ellen Rosenblum "has said over and over again that this is a job where 80 percent of the job is being the government’s lawyer."',
#     'top_k_doc': ["dec 12, 2018  rosenblum said that she considers her job to be the people's lawyer, looking out for the most vulnerable oregonians, and fighting for the ...",
#      "2018-12-12  rosenblum said that she considers her job to be the people's lawyer, looking out for the most vulnerable oregonians, and fighting for the ...",
#      "aug 30, 2012  rosenblum comes to the job after 49 state attorneys general reached a settlement with five of the country's largest lending institutions."]}],
#   'label': 'Half True/False'},
#  {'claim': 'A 4,000-year-old wooden chariot was found near Sanauli, UP, whose wheels are covered with thick copper plates. Copper helmets, comb and a mirror decorated with camel and peacock were also found.',
#   'evidences': [{'questions': 'A 4,000-year-old wooden chariot was found near Sanauli, UP, whose wheels are covered with thick copper plates. Copper helmets, comb and a mirror decorated with camel and peacock were also found.',
#     'top_k_doc': ['2022-01-16  a 4000 year old wooden chariot found near sanauli, up, india. wheels covered with thick plates of copper. also copper helmets found near the ...',
#      'a 4000 year old wooden chariot found near sanauli, up, india. wheels covered with thick plates of copper. also copper helmets found near the chariot....',
#      'sanauli, up, india wheels covered with thick plates of copper. also copper helmets found near the chariot. comb, mirror decorated with camel, peacock found.']}],
#   'label': 'Half True/False'},
#  {'claim': '22-year-old Drone Boy Prathap makes 600 drones using e-waste.',
#   'evidences': [{'questions': '22-year-old Drone Boy Prathap makes 600 drones using e-waste.',
#     'top_k_doc': ["2020-07-09  while 'drone boy' prathap nm has claimed to have made 600 drones using e-waste, not a single photo or video of them exist, and all photographs ...",
#      "2020-07-09  fact-check: did 22-year-old 'drone boy' prathap nm really make 600 drones using e-waste. https://t.co/h2pbeydrpm.",
#      "9 lug 2020  fact-check: did 22-year-old 'drone boy' prathap nm really make 600 drones using e-waste. https://t.co/h2pbeydrpm."]}],
#   'label': 'False'},
#  {'claim': '34 countries including Netherlands and Israel have supported India and Nupur Sharma after her anti-Prophet remarks',
#   'evidences': [{'questions': '34 countries including Netherlands and Israel have supported India and Nupur Sharma after her anti-Prophet remarks',
#     'top_k_doc': ['and india accepts it and trying to rectify it. its not bending but mature politics. i am really wonder to see these people who are supporting nupur sharma. are ...',
#      "jul 1, 2022  nupur sharma's remarks, made in a tv debate in may-end, incensed indian muslims and outraged islamic nations. ... supported ms sharma on social ..."]}],
#   'label': 'False'},
#  {'claim': '"Due to the recent downturn in steel production, more than 13,600 Americans have been laid off and the steel industry is facing billions in losses."',
#   'evidences': [{'questions': '"Due to the recent downturn in steel production, more than 13,600 Americans have been laid off and the steel industry is facing billions in losses."',
#     'top_k_doc': ['due to the recent downturn in steel production, more than 13,600 hardworking americans have been laid-off and the steel industry is facing billions in losses.',
#      '5 avr. 2017  due to the recent downturn in steel production, more than 13,600 hardworking americans have been laid-off and the steel industry is facing ...',
#      'market, more than 12,000 american steel jobs were lost in the past year. has occurred despite financial returns in the chinese industry that']}],
#   'label': 'True'},
#  {'claim': 'Says "Russ Feingold cut Medicare by $523 billion."',
#   'evidences': [{'questions': 'Says "Russ Feingold cut Medicare by $523 billion."',
#     'top_k_doc': ['in the flyer, johnson says, "russ feingold cut medicare by $523 billion. ... made cuts to medicare that will impact 100,000 wisconsin seniors utilizing the medicare advantage program.',
#      'new today from politifact wisconsin: in the u.s. senate race, republican ron johnson says incumbent democrat russ feingold "cut $523 billion from medicare.',
#      '... russ feingold cut medicare by $523 billion. the flyer goes on to state that ... cuts to medicare that will impact 100,000 wisconsin seniors utilizing the medicare ...']}],
#   'label': 'Half True/False'},
#  {'claim': 'Covid-19 vaccine saves us only for 6-9 months, after that Rs 35,000 crore will be evaporated',
#   'evidences': [{'questions': 'Covid-19 vaccine saves us only for 6-9 months, after that Rs 35,000 crore will be evaporated',
#     'top_k_doc': ['2021-12-23  the centre has spent rs 19,675 crore to procure covid-19 vaccines for free of cost supply to states and union territories, according to ...',
#      '1 feb 2021  the finance minister said that two or more covid-19 vaccines will be available soon. the rs 35,000 crore outlay for covid-19 vaccination lays ...',
#      'a single moderna covid-19 vaccine booster dose (0.25 ml) may be administered at least 5 months after completing a primary series of the moderna covid-19 vaccine ...']}],
#   'label': 'False'},
#  {'claim': '"David Perdue voted with liberals” for $10 trillion “in new debt, his out-of-control federal spending is driving inflation through the roof."',
#   'evidences': [{'questions': '"David Perdue voted with liberals” for $10 trillion “in new debt, his out-of-control federal spending is driving inflation through the roof."',
#     'top_k_doc': ['24 mag 2022  in washington insider david perdue voted for trillions of new debt. his out-of-control federal spending is driving inflation through the roof.',
#      "27 feb 2019    senator david perdue (r-georgia). the $22 trillion national debt is ... out-of-control government spending. it's time to do what we said ...",
#      '28 feb 2019  sen. david perdue (r-ga) helped add $2 trillion to the national deficit when he voted for the gop tax scam that lavished wall street banks with ...']}],
#   'label': 'Half True/False'},
#  {'claim': '"According to the FBI, Mexican drug cartels are working with 100,000 street gang members in Chicago alone."',
#   'evidences': [{'questions': '"According to the FBI, Mexican drug cartels are working with 100,000 street gang members in Chicago alone."',
#     'top_k_doc': ['to move their drug shipments to chicago, mexican cartels often employ a series of the chicago crime lab study found that the overall number of',
#      '2017-06-20  where mexican drug cartels and chicago gangs come together is what law enforcement calls the "choke point.',
#      'the indictments targeting the mexican mafia and the la familia drug cartel are the result of an investigation by the bureau of alcohol, tobacco, firearms and explosives; the los angeles sheriffs department; and the los angeles high intensity drug trafficking area (hidta)/southern california drug task force, a federally funded group led by the drug enforcement administration (dea). the southern california drug task force is comprised of federal and local law enforcement agencies, including the dea, the atf, the los angeles police department and the pasadena police department. the mexican mafia is a powerful prison gang that controls much of the drug trade and other criminal activities within california state prisons, county jails and some federal prisons, according to the indictments unsealed this morning. the mexican mafia, whose members are generally senior members of street gangs such as florencia 13, also exercises control over and directs the narcotics trafficking activities of latino street gangs across southern california and in prisons. the indictment concerning the mexican mafia-la familia project represents the largest crackdown on the prison gangs members since the united states attorneys office brought a series of rico cases against the leadership of the prison gang in the 1990s. the members of la familia named in the indictment allegedly oversaw the distribution of methamphetamine and marijuana in the southern california area, as well as provided money and drugs at discounted prices to members of the mexican mafia.']}],
#   'label': 'Half True/False'},
#  {'claim': "No, presidential candidate Obi didn't get 500,000 Nigerians freed from death row in Singapore",
#   'evidences': [{'questions': "No, presidential candidate Obi didn't get 500,000 Nigerians freed from death row in Singapore",
#     'top_k_doc': ['the message states, breaking news: singapore freed 500,000 nigerians on death row after peter obi petitioned on their behalf. the post was first ...',
#      'obi has inspired a zealous movement of mostly youths and disrupted nigerias traditional two-man presidential contest. but can he go all the way and win the vote? obi is igbo, the only of nigerias three largest ethnic groups to have never had a candidate clinching the presidency since the countrys civil war ended in 1970. his running-mate, yusuf datti baba-ahmed, a former senator from the northwestern state of kaduna, is expected to help draw out the northern muslim vote. but now, the trade union-backed labour party is campaigning with peter obi, former two-term governor of the southeastern state of anambra, as leader  and people are taking notice.',
#      "some estimates were as many as 90 million nigerians actually registered to vote. votes that peter obi received. it's no longer a diarchy. i"]}],
#   'label': 'False'},
#  {'claim': 'Public transport is free in Brussels and there is a bus there called "not the 48" which takes you to a mystery location.',
#   'evidences': [{'questions': 'Public transport is free in Brussels and there is a bus there called "not the 48" which takes you to a mystery location.',
#     'top_k_doc': ['not only is public transport free in brussels, but they even have a bus called "not the 48" which takes you to a mystery location if you\'re feeling a bit ...',
#      'not only is public transport free in brussels, but they even have a bus called "not the 48" which takes you to a mystery location if you\'re feeling a bit down ...',
#      'mar 7, 2023  not only is public transport free in brussels, but they even have a bus called "not the 48" which takes you to a mystery location if you\'re ...']}],
#   'label': 'False'},
#  {'claim': 'Walmart is selling bicycles for $6.95 instead of recycling them.',
#   'evidences': [{'questions': 'Walmart is selling bicycles for $6.95 instead of recycling them.',
#     'top_k_doc': ['maybe youve never been tempted to buy a bike at walmart or from another department store, but you almost certainly know someone who didor might. so-called big-box or mass-merchant stores, like sams club or costco, sell 75 percent of all bikes in the us, according to the national bicycle dealers association.',
#      'arrives by thu, nov 2 buy leke mtb mountain bike bicycle headset stem bolts screws and headset cover screw at walmart ... $6.95. add to cart. sold and shipped ...',
#      'how much does it cost? hazardous waste  waste diversion & recycling  safety bicycles  donated to recycle-a-bicycle program; tires all sizes- please call']}],
#   'label': 'False'},
#  {'claim': ' There are 30 tons of plutonium and 40 tons of enriched uranium stored at the Zaporizhzhia NPP, which can be used to create weapons',
#   'evidences': [{'questions': ' There are 30 tons of plutonium and 40 tons of enriched uranium stored at the Zaporizhzhia NPP, which can be used to create weapons',
#     'top_k_doc': ['iaea director general rafael grossi said that 30 tons of plutonium and 40 tons of enriched uranium are stored at the zaporozhye nuclear power plant.',
#      'iaea director general rafael grossi said that 30 tons of plutonium and 40 tons of enriched uranium are stored at the zaporozhye nuclear power ...',
#      '25 mai 2022  there were about 30 tons of plutonium and 40 tons of enriched uranium found on the territory of the zaporizhzhya npp in the city of ...']}],
#   'label': 'False'},
#  {'claim': 'Says Facebook imposes a 7% limit on a user’s sharing.',
#   'evidences': [{'questions': 'Says Facebook imposes a 7% limit on a user’s sharing.',
#     'top_k_doc': ['a long running rumour that causes plenty of confusion amongst facebook users is the assertion that facebook are limiting the reach of the posts you make  either from your timelines or page  to 7%.',
#      "number of facebook monthly active users  facebook currently has 2.9 billion monthly active users (maus)  last quarter's investors' report",
#      "13 sept. 2023  remember, facebook doesn't allow you to require users to share your contest on their personal or friends' timelines. plus, requiring users ..."]}],
#   'label': 'False'},
#  {'claim': 'Says there are "2,000 inadmissible migrants arriving every day"',
#   'evidences': [{'questions': 'Says there are "2,000 inadmissible migrants arriving every day"',
#     'top_k_doc': ['sep 20, 2023  the mayor of eagle pass said 2,500 migrants arrived in one day, part of a recent surge in crossings along the border that has taxed local, state ...',
#      "sep 25, 2023  deputy city manager mario d'agostino said the city was receiving approximately 2,000 arrivals per day as migrants and asylum seekers make their ...",
#      "29 sept. 2023  mexico's foreign minister, alicia brcena, said on september 22 that about 6,000 migrants are arriving each day right now across the country's ..."]}],
# ...
#     'top_k_doc': ["while she was principal, sister mary margaret kreuper embezzled funds intended for her school's tuition, fees, and charitable donations to finance her personal expenses. when sister mary margaret kreuper was 18 years old, she vowed to dedicate her life to the education of children and helping those in need. as principal of st. james catholic school in torrance, california, she certainly did  but while also embezzling more than $835,000 in funds to support her secretive gambling habit. as principal, kreuper was responsible for the money the school garnered in tuition, fees, and charitable donations. she also managed several of the schools bank accounts, including one that had been set up to pay the living expenses of the other nuns who worked there.",
#      "jun 11, 2021  while she was principal, sister mary margaret kreuper embezzled funds intended for her school's tuition, fees, and charitable donations to ...",
#      'feb 7, 2022  mary margaret kreuper, a retired principal of a catholic elementary school, was sentenced to a year in prison monday for embezzling school ...']}],
#   'label': 'True'},
#  {'claim': 'Six masks worn to school by children were sent to a University of Florida laboratory and found to carry at least 11 dangerous pathogens.',
#   'evidences': [{'questions': 'Six masks worn to school by children were sent to a University of Florida laboratory and found to carry at least 11 dangerous pathogens.',
#     'top_k_doc': ['in june 2021, a research facility at the university of florida tested six masks worn by children during their school day and found that at least 11 disease-causing pathogens were present on the mask material.',
#      '15 juin 2021  the resulting report found that five masks were contaminated with bacteria, parasites, and fungi, including three with dangerous pathogenic and ...',
#      'gainesville parents in florida concerned about the harm caused to their children wearing face masks all day at school in 90 f weather sent out six masksfive that were worn by children ages 6 to 11 for five to eight hours at school, and one worn by an adultto be analyzed for contaminants at the university of floridas mass spectrometry research and education center. of the six masks, three were surgical, two cotton, and a poly gaiter. masks that have not been worn and a t-shirt worn at school acted as the control samples. a laboratory at the university of florida that recently analyzed a small sample of face masks, detected the presence of 11 dangerous pathogens that included bacterias that cause diphtheria, pneumonia, and meningitis.']}],
#   'label': 'Half True/False'},
#  {'claim': 'Video shows a family of five being swept away in floods in Pakistan.',
#   'evidences': [{'questions': 'Video shows a family of five being swept away in floods in Pakistan.',
#     'top_k_doc': ['2022-09-09  some of the footage showed cars and buildings being swept away by the massive floods. ... families affected by floods in balochistan, pakistan, to ...',
#      'pakistan floods: millions lives are living in disarray as pakistan has been witnessing the worst flooding in the history of the country. till now, the catastrophic floods have affected approximately 33 million people  about 14% of pakistans population  causing death, damage, displacement and loss whose effects will be felt for months and years to come. people are sharing heart-wrenching videos on social media where several homes and roads were swept away in the devastating deluge.',
#      'warning, disturbing content: family shown at waterfall before 3 members drown duration 0:12 featured video warning: this video contains images that viewers may find disturbing as it shows a family at crescent falls on tuesday before partab rai oad, his wife venjhar oad and their nephew, anoop kumar oad, drowned. the drowning deaths of a mother, father and nephew who were swept under a powerful waterfall in west-central alberta on tuesday have left their family shattered. warning: this video shows shows the family before the accident and contains images that viewers may find disturbing.']}],
#   'label': 'False'},
#  {'claim': "Bill Gates told G-20 leaders that 'death panels'will soon be necessary",
#   'evidences': [{'questions': "Bill Gates told G-20 leaders that 'death panels'will soon be necessary",
#     'top_k_doc': ['2023-05-20  claim: a video shows billionaire philanthropist bill gates telling world leaders at the 2022 g-20 summit that death panels will soon be ...',
#      'for his part, gates is using the forum to instruct world leaders that death panels will be necessary in the near future in order to end the lives of sick and unwell people due to very, very high medical costs. bill gates plans for death panels mirrors the language used by the world economic forum regarding euthanasia and the canadian governments devilish new solution to solve inflation, homelessness, skyrocketing crime, and food shortages  euthanasia for the poor. unelected world health czar bill gates has told world leaders that its time to start talking about death panels that sentence ordinary, law-abiding people to death for the crime of being of no use to the elite.',
#      '2023-10-08  bill gates about death panels: in the near future, such panels will be needed to end the lives of sick and unhealthy people due to "very, ...']}],
#   'label': 'False'},
#  {'claim': 'Vaccination is only artificial, it can only produce artificial immunity for three months. That’s why there is a booster...',
#   'evidences': [{'questions': 'Vaccination is only artificial, it can only produce artificial immunity for three months. That’s why there is a booster...',
#     'top_k_doc': ["artificial' vaccine-induced immunity. this is a grave mistake and a will be disadvantaged by those requirements that recognise only vaccine-induced immunity.",
#      '2021-11-02  is that option only for fully vaccinated people seeking a booster shot, or is it open to previously unvaccinated people, too? in this context, ...',
#      'active immunity can be acquired through natural immunity or vaccine-induced immunity. ... however, passive immunity lasts only for a few weeks or months. only ...']}],
#   'label': 'Half True/False'},
#  {'claim': 'Jan. 6 defendants “are being held in prison without being charged.”',
#   'evidences': [{'questions': 'Jan. 6 defendants “are being held in prison without being charged.”',
#     'top_k_doc': ['lake said defendants were being held in "prison" without being charged, but defendants are held pre-trial in jails. the majority of defendants awaiting trial have been released from jail pending the outcome of their case. the number of defendants detained pretrial is between 75 and 85 at any given time, according to the u.s. attorney\'s office. lake said jan. 6 defendants "are being held in prison without being charged." lake did not cite any particular defendants during her interview, and her campaign didnt respond to our request for evidence.',
#      '(a) defendant in jail. no defendant shall be detained in jail on a charge, without a trial, for a period in aggregate embracing more than six (6) months ...15 pages',
#      '6 juil. 2023  approximately 935 defendants have been charged with entering or remaining in a restricted federal building or grounds. ... federal charges, many ...']}],
#   'label': 'False'},
#  {'claim': 'In einem Video sagt ein Landwirt, sein geernteter Weizen habe einen Proteingehalt von 8,8 Prozent. Das sei zu niedrig, um damit Brot zu backen. Schuld daran sei die Düngeverordnung.',
#   'evidences': [{'questions': 'In einem Video sagt ein Landwirt, sein geernteter Weizen habe einen Proteingehalt von 8,8 Prozent. Das sei zu niedrig, um damit Brot zu backen. Schuld daran sei die Düngeverordnung.',
#     'top_k_doc': ['einige bauern befrchten durch die neuen regeln zustzliche belastungen und ernteeinbuen  auch wre die backfhigkeit von weizen gefhrdet, wenn durch die reduzierte dngung der proteingehalt im weizen sinke. wir kommen auch ohne hohen proteingehalt aus und verwenden nur getreide aus kontrolliert biologischem anbau!',
#      'aug 24, 2022  allerdings ist der proteingehalt des getreides niedriger als sonst. das ist ein problem fr die landwirte und knnte auch fr die verbraucher ...',
#      'einer der bekanntesten inhaltsstoffe von weizen ist das gluten oder klebereiwei. es besteht aus einem gemisch von proteinen, die vor allem beim brot backen eine wichtige bedeutung haben. der kleber sorgt dafr, dass der teig das entstehende kohlendioxid hlt, damit der teig aufgehen kann. auerdem ist der kleber dafr verantwortlich, dass das fertige brot seine form behlt, denn er stellt in trockener form das sogenannte klebergerst dar. allerdings bewirkt gluten bei manchen menschen auch eine berempfindlichkeit (sogenannte zliakie).']}],
#   'label': 'False'},
#  {'claim': 'The FBI discovered a mysterious photograph behind a dumpster in 1982 whichshoweda man in a bunny mask dragging a woman into a building.',
#   'evidences': [{'questions': 'The FBI discovered a mysterious photograph behind a dumpster in 1982 whichshoweda man in a bunny mask dragging a woman into a building.',
#     'top_k_doc': ['legend: "the fbi discovered a mysterious photograph behind a dumpster in 1982 which showed a man in a bunny mask dragging a woman into a building."',
#      '20 sept. 2019  contrary to popular belief, the photograph of a man in a bunny mask dragging a woman into a building is a piece of art, not a piece of evidence.',
#      'in 1982, this photograph was found in a dumpster behind a restaurant in georgia. the fbi examined it and found.']}],
#   'label': 'False'},
#  {'claim': '“We created more new jobs in two years than any president did in their entire term.”',
#   'evidences': [{'questions': '“We created more new jobs in two years than any president did in their entire term.”',
#     'top_k_doc': ['jobs created in two years than any president has ever created in four years. in any four years than my predecessor. nearly 25% of the entire',
#      'more jobs created in two years than any president has ever created in four years. two years ago, covid had shut down our businesses, closed',
#      'you know, as of this month, weve created 12 million new jobs. (applause.) we created more new jobs in two years than any president did in their entire term. (applause.) and thats because of you. the strongest two years of growth in history by a longshot  3.4 percent unemployment, the lowest in 54 years. (applause.)']}],
#   'label': 'Half True/False'},
#  {'claim': '"When the Covid pandemic hit our country, we had an ICU bed capacity of only 180 beds countrywide ... We increased the ICU bed capacity by 502% during the Covid period."',
#   'evidences': [{'questions': '"When the Covid pandemic hit our country, we had an ICU bed capacity of only 180 beds countrywide ... We increased the ICU bed capacity by 502% during the Covid period."',
#     'top_k_doc': ['dec 24, 2020  ... (icu) beds available across the country, and many were completely full. ... covid-19 patients were at more than 95 percent icu bed capacity. in ...',
#      'by mp kerlin  2021  cited by 41  ... critical care capacity during the covid-19 pandemic. weighted ... prior to this pandemic, the united states had more icu beds per capita than ...',
#      'the data for england as a whole appear to suggest that during much of 2020-21 there was available icu capacity. but things are more complex than they seem. the burden of covid was not equitably distributed across hospitals or regions, and neither are icu beds. most hospitals had periods of time where the number of patients requiring intensive care exceeded the available capacity. cases admitted to icu with covid are complex and patients are very ill. in 2020-21, more than one in three patients admitted to icu with covid died there.']}],
#   'label': 'False'},
#  {'claim': 'The five states that outlaw collective bargaining for teachers all rank below 44th in the nation in test scores, while Wisconsin ranks 2nd.',
#   'evidences': [{'questions': 'The five states that outlaw collective bargaining for teachers all rank below 44th in the nation in test scores, while Wisconsin ranks 2nd.',
#     'top_k_doc': ['only five states do not allow collective bargaining for educators, effectively banning teachers unions. those states and their sat/act rankings are as follows:',
#      '23 feb 2011  @trek: 5 states forbid collective bargaining for educators: sc, nc, ga, tx, & va. their national rank in act scores: 50th, 49th, 48th, 47th, ...',
#      "given that the law prohibited collective bargaining over teacher compensation schemes my results align with other literature finding that wisconsin's act 10"]}],
#   'label': 'False'},
#  {'claim': 'Video shows Joe Biden waved to nobody after a July 2023 speech in Lithuania',
#   'evidences': [{'questions': 'Video shows Joe Biden waved to nobody after a July 2023 speech in Lithuania',
#     'top_k_doc': ['joe biden is being called out by social media users today as a video appears to show him waving to an empty field as he gets off his plane. but was he actually waving at no one? a video has gone viral online that seemingly shows us democratic presidential candidate joe biden waving at nobody.',
#      "13 juil. 2023  fact check: biden did not wave 'to nobody' after his speech in lithuania -- audience included... 3 views  2 months ago ...more ...",
#      '8 lug 2023  joe biden, president of the united sates will make a public speech at vilnius university in vilnius, lithuania, on wednesday, july 12, ...']}],
#   'label': 'False'},
#  {'claim': "A WhatsApp video called 'India is doing it' will hack the phone in 10 seconds.",
#   'evidences': [{'questions': "A WhatsApp video called 'India is doing it' will hack the phone in 10 seconds.",
#     'top_k_doc': ["oct 22, 2020  if you have received a message on whatsapp claiming that a viral video called 'india is doing it' can hack your phone in 10 seconds if you watch ...",
#      "22 oct. 2020  if you have received a message on whatsapp claiming that a viral video called 'india is doing it' can hack your phone in 10 seconds if you ...",
#      "22 ott 2020  if you have received a message on whatsapp claiming that a viral video called 'india is doing it' can hack your phone in 10 seconds if you ..."]}],
#   'label': 'False'},
#  {'claim': 'A photograph shows the offspring of a woman who gave birth to 69 children.',
#   'evidences': [{'questions': 'A photograph shows the offspring of a woman who gave birth to 69 children.',
#     'top_k_doc': ['does this photograph show the offspring of a woman who gave birth to 69 children? a photograph shows the offspring of a woman who gave birth to 69 children.',
#      'super mom: 69 children born to one woman - youtube behauptung: a photograph shows the offspring of a woman who gave birth to 69 children. sql server allow ...',
#      'the greatest officially recorded number of children born to one mother is 69, to the wife of feodor vassilyev (b. 1707c .1782), a peasant from shuya, russia. in 27 confinements she gave birth to 16 pairs of twins, seven sets of triplets and four sets of quadruplets.']}],
#   'label': 'Half True/False'},
#  {'claim': '"We\'ve got some 37-million of our fellow citizens who are living in poverty; about 12-million or 13-million are children."',
#   'evidences': [{'questions': '"We\'ve got some 37-million of our fellow citizens who are living in poverty; about 12-million or 13-million are children."',
#     'top_k_doc': ["we've got some 37 million of our fellow citizens who are living in poverty; about 12 million or 13 million are children. one of the things i",
#      '21 mag 2018  today 12.8 million children live in poverty, an increase of 1.2 million children since the president took office. if adopted by congress ...',
#      "2021-01-12  in america, nearly 11 million children are poor. that's 1 in 7 kids, who make up almost one-third of all people living in poverty in this ..."]}],
#   'label': 'True'},
#  ...]

# %%
with open("../../data/English/decomposed_questions_with_mapped_bm25_evidence/train_claimdecomp_evidence_question_mapping.json") as f:
  train_claimdecomp_evidence_question_mapping = json.load(f)

# %%
train_claimdecomp_evidence_question_mapping
# Out:
# [{'claim': 'In her budget speech, Nirmala Sitharaman claimed that the Government distributed 35,000 crore LED bulbs in the country.',
#   'evidences': [{'questions': 'did nirmala sitharaman claim that the government distributed 35,000 crore led bulbs in the country?\n',
#     'top_k_doc': ["conclusion: nirmala sitharaman didn't claim that govt distributed 35,000 crores led bulbs. from the video fo the speech it is clear that she said 35 crores. nirmala sitharaman didn't claim that govt distributed 35,000 crores led bulbs. from the video of the speech, it is clear that she said 35 crores, not 35000 crores."]},
#    {'questions': ' is there evidence to support the claim that the government distributed 35,000 crore led bulbs?\n',
#     'top_k_doc': ["conclusion: nirmala sitharaman didn't claim that govt distributed 35,000 crores led bulbs. from the video fo the speech it is clear that she said 35 crores. nirmala sitharaman didn't claim that govt distributed 35,000 crores led bulbs. from the video of the speech, it is clear that she said 35 crores, not 35000 crores."]},
#    {'questions': ' are there records of the government distributing 35,000 crore led bulbs in the country?',
#     'top_k_doc': ['24 mar 2022  according to information recently tabled in parliament, the total number of led bulbs distributed under ujala, since its launch till around ...']}],
#   'label': 'False'},
#  {'claim': 'Florida residents affected by Hurricane Irma can receive $197 in food stamp benefits, but only if they can show that their homes lost power for more than two hours.',
#   'evidences': [{'questions': 'do florida residents affected by hurricane irma qualify for $197 in food stamp benefits?\n',
#     'top_k_doc': ['oct 11, 2017  south floridians who lost food, income or property during hurricane irma may be eligible for special cards worth hundreds of dollars to ...']},
#    {'questions': ' is it required for florida residents to show proof of their homes losing power for more than two hours to receive food stamp benefits?\n',
#     'top_k_doc': ['but the federal government sets the food stamps benefit amount at, on average, roughly $4 a day per person. yes, someone could save up their monthly ...']},
#    {'questions': ' is the $197 in food stamp benefits only available to florida residents affected by hurricane irma?',
#     'top_k_doc': ['oct 11, 2017  south floridians who lost food, income or property during hurricane irma may be eligible for special cards worth hundreds of dollars to ...']}],
#   'label': 'False'},
#  {'claim': "Bill Gates' foundation tested a polio vaccine in India that left at least 490,000 children paralyzed",
#   'evidences': [{'questions': "did bill gates' foundation test a polio vaccine in india?\n",
#     'top_k_doc': ['490,000 children paralyzed. "bill gates foundation tested a polio vax ... gates foundation had tested polio vaccine in india between 2000 & 2017 and had paralysed']},
#    {'questions': " did the polio vaccine tested by bill gates' foundation cause paralysis in children?\n",
#     'top_k_doc': ['490,000 children paralyzed. "bill gates foundation tested a polio vax ... gates foundation had tested polio vaccine in india between 2000 & 2017 and had paralysed']},
#    {'questions': " is there evidence to support the claim that at least 490,000 children were paralyzed due to the polio vaccine tested by bill gates' foundation in india?",
#     'top_k_doc': ['490,000 children paralyzed. "bill gates foundation tested a polio vax ... gates foundation had tested polio vaccine in india between 2000 & 2017 and had paralysed']}],
#   'label': 'False'},
#  {'claim': 'SaysHillary Clinton "took 13 hours to send help to Americans under fire" during the terrorist attack in Benghazi.',
#   'evidences': [{'questions': 'did hillary clinton take 13 hours to send help to americans during the terrorist attack in benghazi?\n',
#     'top_k_doc': ['jan 21, 2016  ... and hillary clinton lied shamelessly about the benghazi attacks of september 11, 2012 ... terrorists who assaulted the americans in ever-larger ...']},
#    {'questions': ' was there a terrorist attack in benghazi?\n',
#     'top_k_doc': ['the 2012 benghazi attack was a coordinated attack against two united states government facilities in benghazi, libya, by members of the islamic militant ...']},
#    {'questions': ' did americans come under fire during the attack in benghazi?',
#     'top_k_doc': ["... came under ferocious attack by a heavily armed group of islamic terrorists. ... terrorist attacks that night on the cia's annex in benghazi. washington ..."]}],
#   'label': 'False'},
#  {'claim': '"Send your postcards to 5 key states to decertify fraud” in the 2020 election.',
#   'evidences': [{'questions': 'did someone encourage people to send postcards to key states in order to decertify fraud in the 2020 election?\n',
#     'top_k_doc': ['2021-03-15  this included efforts to send threatening e-mails to american citizens and to amplify concerns about voter fraud in the election.  in a ...']},
#    {'questions': ' is there a belief that fraud occurred in the 2020 election?\n',
#     'top_k_doc': ['that there had been outcome-determinative fraud in the 2020 presidential election. falsely alleging "massive election fraud" accomplished']},
#    {'questions': ' is there a plan to decertify fraud in the 2020 election by sending postcards to key states?',
#     'top_k_doc': ['2021-03-15  this included efforts to send threatening e-mails to american citizens and to amplify concerns about voter fraud in the election.  in a ...']}],
#   'label': 'False'},
#  {'claim': 'Under HR 1, a person can still vote if they are 16, in the U.S. illegally, have no ID and have not registered to vote',
#   'evidences': [{'questions': 'does hr 1 allow 16-year-olds to vote?\n',
#     'top_k_doc': ["in some states, 16- and 17-year-olds can pre-register to vote so that upon their 18th birthday, they can participate in the federal election process. the lawmakers' amendment would expand these efforts so that people as young as 16-years-old can elect members of congress and the president of the united states. washington, d.c.  u.s. reps. grace meng (d-ny), ayanna pressley (d-ma) and jan schakowsky (d-il) today reintroduced an amendment to lower the federal election voting age from 18-years-old to 16-years-old. the measure was reintroduced as an amendment to the for the people act (h.r. 1) ahead of this week's debate on the bill in the house of representatives. h.r. 1 is a sweeping campaign and voter reform bill that seeks to improve access to the ballot box, voter rights and election integrity, among other things."]},
#    {'questions': ' does hr 1 allow undocumented immigrants to vote?\n',
#     'top_k_doc': ['nov 6, 2018  undocumented immigrants are part of the political community just like any other resident. they should have full voting rights.']},
#    {'questions': ' does hr 1 allow individuals without id to vote?',
#     'top_k_doc': ['in addition, a voter who does not have a valid photo id in his or her possession at the polls shall be permitted to vote if the individual is positively identified by two election officials as a voter on the poll list who is eligible to vote and the election officials sign a sworn affidavit so stating.']}],
#   'label': 'Half True/False'},
#  {'claim': 'Violence video shows rival groups fighting at 2022 football tournament in Democratic Republic of Congo, not March 2023 protests in Kenya',
#   'evidences': [{'questions': 'is there a video showing rival groups fighting at a football tournament in the democratic republic of congo?\n',
#     'top_k_doc': ['violent video shows rival groups fighting at 2022 football tournament in democratic republic of congo, not march 2023 protests in kenya. march 30, 2023. 0.']},
#    {'questions': ' are there protests scheduled for march 2023 in kenya?\n',
#     'top_k_doc': ['may 4, 2023  kenya protests. police block a street in nairobi on march 27, 2023, during a rally called by opposition leader raila odinga, who says the ...']},
#    {'questions': ' is there evidence linking the video to the 2023 protests in kenya?',
#     'top_k_doc': ['demonstrations have significantly increased in kenya in 2023, primarily driven by azimio leader odinga mobilizing his supporters against the kenya kwanza government led by william ruto. from 1 january to 15 september 2023, acled records over 840 demonstration events across kenya; 26% of the demonstrations recorded thus far drew intervention from security forces  compared to only 15% of demonstrations in 2022. police forces intervened in around half of the demonstrations organized by the azimio coalition in 2023. additionally, police intervention has also become more lethal, resulting in at least 35 deaths  all during azimio-led demonstrations. since january 2023, kenya has witnessed a surge in cases of police violence in the context of anti-government demonstrations organized by the opposition party, azimio la umoja (resolution for unity) one kenya coalition party. led by the former prime minister and current opposition leader, raila odinga, the azimio coalition has staged multiple waves of protests throughout the year to voice grievances such as electoral injustice, high living costs, and tax hikes. the first round of protests took place in march, followed by subsequent waves in may and july. during these demonstrations, there have been numerous reports of police injuring and killing demonstrators, as they have increasingly resorted to excessive use of force in their efforts to contain and suppress the protests. this wave of punitive policing is occurring in contrast to the kenya kwanza (kenya first) alliances rise to power on a heavily human rights-focused platform. this report examines the marked increase in violent police interventions during the latest round of anti-government demonstrations. the excessive use of violence undermines trust in kenyas law enforcement bodies and fails to ensure accountability or rein in violence, which may contribute to escalating the protest movement. in july alone, the azimio coalition organized over 150 demonstration events across the country to protest against the passing of a finance bill enacting contested tax hikes. while the protests in march and may were limited to areas perceived to be the oppositions stronghold, such as the capital city of nairobi, the coastal city of mombasa, and other parts of western kenya, the july protests extended beyond the political divide and spread to counties such as laikipia, meru, nyeri, and muranga, all of which are considered strongholds of the presidents coalition. the protests, according to odinga, were a matter for all kenyans rather than a party-based issue. however, in the north rift region  and president rutos home region  azimio supporters and their leaders stayed away from the protests, alleging threats and intimidation from police and kenya kwanza supporters.']}],
#   'label': 'False'},
#  {'claim': 'In Virginia, "people are going and getting marriage licenses who are 12 and 13, and 14 and 15 years old."',
#   'evidences': [{'questions': 'is it legal for 12 and 13-year-olds to obtain marriage licenses in virginia?\n',
#     'top_k_doc': ['virginia marriage license requirements. in virginia, you need to be at least 18 years old in order to apply for a marriage license. while many ...']},
#    {'questions': ' are there documented cases of 12 and 13-year-olds obtaining marriage licenses in virginia?\n',
#     'top_k_doc': ['under current law, 16 and 17-year-olds can marry with parental consent and anyone under the age of 16 can be married in west virginia with a certificate from a judge. he also cited statistics from the director of vital statistics that showed there were only six marriages of 14-year-olds and 15-year-olds in west virginia between 2012 and 2021, all to people aged 21 or younger. west virginia has the highest rate of child marriages in the country, and woelfel said that with most of those marriages happening with 16-year-olds and 17-year-olds, the amendment would not significantly address the issue.']},
#    {'questions': ' is there evidence to support the claim that 14 and 15-year-olds are obtaining marriage licenses in virginia?',
#     'top_k_doc': ['under current law, 16 and 17-year-olds can marry with parental consent and anyone under the age of 16 can be married in west virginia with a certificate from a judge. he also cited statistics from the director of vital statistics that showed there were only six marriages of 14-year-olds and 15-year-olds in west virginia between 2012 and 2021, all to people aged 21 or younger. west virginia has the highest rate of child marriages in the country, and woelfel said that with most of those marriages happening with 16-year-olds and 17-year-olds, the amendment would not significantly address the issue.']}],
#   'label': 'True'},
#  {'claim': '“scientists find virus contains tiny chunk of DNA that matches sequence patented by Moderna THREE YEARS before pandemic began”',
#   'evidences': [{'questions': 'is there a tiny chunk of dna in the virus that matches a sequence patented by moderna?\n',
#     'top_k_doc': ['now scientists find virus contains tiny chunk of dna that matches sequence patented by moderna three years before pandemic began. dan het']},
#    {'questions': ' did moderna patent a sequence that matches a chunk of dna in the virus?\n',
#     'top_k_doc': ['now scientists find virus contains tiny chunk of dna that matches sequence patented by moderna three years before pandemic began. dan het']},
#    {'questions': ' did scientists discover the presence of a dna sequence in the virus that matches a sequence patented by moderna?',
#     'top_k_doc': ['now scientists find virus contains tiny chunk of dna that matches sequence patented by moderna three years before pandemic began. dan het']}],
#   'label': 'False'},
#  {'claim': 'Minnesota expected to get 16 inches of snowfall within the next week!',
#   'evidences': [{'questions': 'is there a weather forecast predicting 16 inches of snowfall in minnesota within the next week?\n',
#     'top_k_doc': ['new snow total predictions were down for wednesday night. by 9:30 p.m., the expected final totals ended on the lower end of what was deemed possible by the nws, said meteorologist mike griesinger. but parts of western minnesota were slated to get a walloping 15 or 16 inches overnight. the twin cities metro area was forecast to see a more modest 8 to 12 inches overnight, while northern minnesota was in line for 12 to 18 inches.']},
#    {'questions': ' has minnesota experienced heavy snowfall in the past?\n',
#     'top_k_doc': ['minnesota winters, which many experts say encompasses late november to late march, are truly unpredictable. in april 2018, the twin cities alone received a record 26 inches of snowfall for the month. that said, minnesota does not receive the most snowfall on average, even within the continental united states. when it comes to individual cities, places like blue canyon, calif., and mount washington, n.h., received, in some cases, nearly three times the amount of average snowfall during the winter months than that of snowy minnesota cities like international falls. however, minnesota is truly cold in comparison to other states. minnesota had the second-coldest temperatures from december to february between 1971 and 2000, ringing in at a mere 12 degree average. according to meteorologist paul douglas, if you look at average winter temperatures over an entire state, alaska appears to be the coldest state in the country, followed by north dakota and then minnesota.']},
#    {'questions': ' are there any weather warnings or advisories issued for minnesota regarding snowfall?',
#     'top_k_doc': ['minnesota winters, which many experts say encompasses late november to late march, are truly unpredictable. in april 2018, the twin cities alone received a record 26 inches of snowfall for the month. that said, minnesota does not receive the most snowfall on average, even within the continental united states. when it comes to individual cities, places like blue canyon, calif., and mount washington, n.h., received, in some cases, nearly three times the amount of average snowfall during the winter months than that of snowy minnesota cities like international falls. however, minnesota is truly cold in comparison to other states. minnesota had the second-coldest temperatures from december to february between 1971 and 2000, ringing in at a mere 12 degree average. according to meteorologist paul douglas, if you look at average winter temperatures over an entire state, alaska appears to be the coldest state in the country, followed by north dakota and then minnesota.']}],
#   'label': 'False'},
#  {'claim': '“In 2020, there was a 64% drop in cases of GBVF compared to the same period in 2019.”',
#   'evidences': [{'questions': 'did the number of cases of gbvf decrease in 2020 compared to 2019?\n',
#     'top_k_doc': ['number of gbvf cases cleared, and (ii) case report on the implementation of the south african national strategic plan on gbvf may 2020.']},
#    {'questions': ' was there a 64% decrease in cases of gbvf in 2020 compared to 2019?\n',
#     'top_k_doc': ['received, compared to 111 reports in 2018/2019 and 99 in 2019/2020. this means that ... number of gbvf cases cleared, and (ii) case management system upgraded.']},
#    {'questions': ' is there evidence to support the claim of a 64% drop in cases of gbvf in 2020 compared to 2019?',
#     'top_k_doc': ['received, compared to 111 reports in 2018/2019 and 99 in 2019/2020. this means that ... number of gbvf cases cleared, and (ii) case management system upgraded.']}],
#   'label': 'False'},
#  {'claim': '“President Obama and Vice President Biden never even tried to fix this (police reforms) during their eight-year period.”',
#   'evidences': [{'questions': 'did president obama and vice president biden make any efforts to address police reforms during their eight-year period?\n',
#     'top_k_doc': ["... biden and the obama state department's anti-corruption efforts. in fact, many ... vice president biden did not resolve this conflict of interest. instead, he ..."]},
#    {'questions': ' is it true that president obama and vice president biden did not attempt to fix police reforms during their time in office?\n',
#     'top_k_doc': ["... biden and the obama state department's anti-corruption efforts. in fact, many ... vice president biden did not resolve this conflict of interest. instead, he ..."]},
#    {'questions': ' did president obama and vice president biden ignore the issue of police reforms during their eight-year period?',
#     'top_k_doc': ["... biden and the obama state department's anti-corruption efforts. in fact, many ... vice president biden did not resolve this conflict of interest. instead, he ..."]}],
#   'label': 'False'},
#  {'claim': 'Ahead of Karnataka Assembly elections, Congress releases its manifesto that promises seven “Muslim-only” schemes.',
#   'evidences': [{'questions': 'does the congress manifesto for karnataka assembly elections promise seven "muslim-only" schemes?\n',
#     'top_k_doc': ["toi newswrap: congress promises seven 'muslim only' schemes in telangana manifesto | in its draft manifesto for telangana polls, congress"]},
#    {'questions': ' are there any schemes in the congress manifesto for karnataka assembly elections that are exclusively for muslims?\n',
#     'top_k_doc': ["toi newswrap: congress promises seven 'muslim only' schemes in telangana manifesto | in its draft manifesto for telangana polls, congress"]},
#    {'questions': ' is the congress manifesto for karnataka assembly elections discriminatory towards non-muslims?',
#     'top_k_doc': ["toi newswrap: congress promises seven 'muslim only' schemes in telangana manifesto | in its draft manifesto for telangana polls, congress"]}],
#   'label': 'False'},
#  {'claim': 'Bill Nelson "leased land that he owned for six cows, taking advantage of an agricultural tax loophole to dodge $43,000 in taxes just last year."',
#   'evidences': [{'questions': 'did bill nelson lease land that he owned for six cows?\n',
#     'top_k_doc': ['feb 15, 2012  nelson does not live there or own the cows. he leases the land, at no cost, to a cattle operation. nelson says he gets to preserve undeveloped ...']},
#    {'questions': ' did bill nelson take advantage of an agricultural tax loophole?\n',
#     'top_k_doc': ['10 ott 2012  did bill nelson take advantage of a tax loophole to avoid paying higher taxes? ... the area is where nelson grew up and has been farm or pasture ...']},
#    {'questions': ' did bill nelson dodge $43,000 in taxes just last year?',
#     'top_k_doc': ["4 oct. 2018  rick scott claims bill nelson voted for higher taxes 349 times. that number is very unreliable. here's why."]}],
#   'label': 'Half True/False'},
#  {'claim': 'The video shows G20 delegates having lunch with their hands',
#   'evidences': [{'questions': 'is there a video showing g20 delegates having lunch?\n',
#     'top_k_doc': ["antalya: the two-day g20 summit at the picturesque turkish coastal resort town is being attended by more than 13,000 delegates from as many as 26 countries and seven international organisations.top global leaders, including us president barack obama , russian president vladimir putin and indian prime minister narendra modi , who have congregated here for the summit are being provided security by over 12,000 personnel.as many as 20 hotels, including the main summit meeting salon and the international press centre, have been booked for the international delegates attending the g20 summit. five hotels for turkish delegations have also been booked, according to g20 antalya statistics.in addition to eight medical motorcycles in the region, 68 ambulances have been kept in readiness for any eventuality.some 13,000 delegates and 3,000 journalists from across the world have converged here for the 10th g-20 summit, being held at the regnum carya hotel convention centre in the belek town of antalya's serik district. besides, there is a strong army of 40,000 support staff to assist the delegates.the heightened security measures, including over 12,000 security personnel, drone detection equipment, 350 mobile cameras with licence-plate recording and face-recognition systems, follow the audacious terror attacks in paris on friday night.french president francois hollande had to cancel his visit at the last moment following the deadly terror attack in paris, which killed 129 people, leaving over 352 injured.german chancellor angela merkel, japanese prime minister shinzo abe and chinese president xi jinping , saudi arabia's king salman and imf managing director christine lagarde , among others, are attending the summit.besides modi, india is being represented by niti aayog vice-chairman arvind panagariya, foreign secretary s jaishankar and economic affairs secretary shaktikanta das.the g-20 brings the 19 largest economic powers and the eu together, representing 85 per cent of the world's economy , 75 per cent of trades and two-thirds of the world's population."]},
#    {'questions': ' are the g20 delegates seen in the video eating with their hands?\n',
#     'top_k_doc': []},
#    {'questions': ' is it true that the video shows g20 delegates having lunch?',
#     'top_k_doc': []}],
#   'label': 'False'},
#  {'claim': '"The city of Columbus would save $41 million a year if employees had to contribute to their own, guaranteed-check pensions."',
#   'evidences': [{'questions': 'would the city of columbus save $41 million a year if employees did not contribute to their own, guaranteed-check pensions?\n',
#     'top_k_doc': ['an employee from the city of columbus, for which there is a pension contribution. high cost claims for medical and behavioral health (semi-']},
#    {'questions': ' do employees currently contribute to their own, guaranteed-check pensions in the city of columbus?\n',
#     'top_k_doc': ['an employee from the city of columbus, for which there is a pension contribution. high cost claims for medical and behavioral health (semi-']},
#    {'questions': ' is there evidence to support the claim that the city of columbus would save $41 million a year if employees had to contribute to their own, guaranteed-check pensions?',
#     'top_k_doc': ['an employee from the city of columbus, for which there is a pension contribution. high cost claims for medical and behavioral health (semi-']}],
#   'label': 'True'},
#  {'claim': 'Honeybees were not considered “endangered” in the U.S. as of September 2023.',
#   'evidences': [{'questions': 'is there a classification system for the conservation status of honeybees?\n',
#     'top_k_doc': ["oct 23, 2023  honeybees aren't endangered but have faced serious annual losses ... we have good data about the health of domestic honeybee populations, because ..."]},
#    {'questions': ' is the conservation status of honeybees determined by government agencies?\n',
#     'top_k_doc': ['honeybees are not endangered, mainly because they are globally distributed and primarily managed by beekeepers. these important pollinators arent actually native to the united states; they were brought over from europe by colonizers in the 17th century to use for honey and beeswax. eventually, some of the managed bees escaped and formed wild honeybee colonies, but the majority of honeybees are still managed by humans.']},
#    {'questions': ' is the conservation status of honeybees regularly updated?',
#     'top_k_doc': ["oct 23, 2023  honeybees aren't endangered but have faced serious annual losses ... we have good data about the health of domestic honeybee populations, because ..."]}],
#   'label': 'True'},
#  {'claim': "The Domino's pizza chain is offering coupons for two free large pizzas to social media users who fill out an online survey.",
#   'evidences': [{'questions': "is domino's pizza chain offering coupons for two free large pizzas?\n",
#     'top_k_doc': ["9 apr 2020  the latest scam popping up on your newsfeed is a coupon for two free large pizzas from domino's."]},
#    {'questions': ' is the offer of free pizzas only available to social media users?\n',
#     'top_k_doc': ['oct 11, 2019  free pizza is possible with the pizza hut rewards offers. ... if you take the survey on the receipt they email you a $10 off $20 or more coupon as ...']},
#    {'questions': ' is the coupon for two free large pizzas obtained by filling out an online survey?',
#     'top_k_doc': ["9 apr 2020  the latest scam popping up on your newsfeed is a coupon for two free large pizzas from domino's."]}],
#   'label': 'False'},
#  {'claim': 'Does This Video Show Moldova Residents Blocking A NATO Column In 2022?',
#   'evidences': [{'questions': 'is there a video showing moldova residents blocking a nato column in 2022?\n',
#     'top_k_doc': ['the news agency avia.pro obtained exclusive video footage showing how moldovan citizens blocked the movement of the nato military convoy, blocking the road and preventing the western military from advancing in the originally intended direction. citizens of moldova blocked the movement of a convoy of nato military equipment in the area of the settlement novi anenii. a column of military equipment was seen here against the background of mass protests expected on september 18 in moldova against the actions of the government - earlier, the movement of military equipment of the moldovan army was already recorded in a number of regions of moldova. judging by the video footage, we are talking about a convoy of at least 10 pieces of military equipment from nato countries. moreover, which is very remarkable, there are no identification marks on the latter. this only confirms the version that nato forces can really try to use to suppress protests against the moldovan authorities.']},
#    {'questions': ' are the residents in the video from moldova?\n',
#     'top_k_doc': ['the news agency avia.pro obtained exclusive video footage showing how moldovan citizens blocked the movement of the nato military convoy, blocking the road and preventing the western military from advancing in the originally intended direction. citizens of moldova blocked the movement of a convoy of nato military equipment in the area of the settlement novi anenii. a column of military equipment was seen here against the background of mass protests expected on september 18 in moldova against the actions of the government - earlier, the movement of military equipment of the moldovan army was already recorded in a number of regions of moldova. judging by the video footage, we are talking about a convoy of at least 10 pieces of military equipment from nato countries. moreover, which is very remarkable, there are no identification marks on the latter. this only confirms the version that nato forces can really try to use to suppress protests against the moldovan authorities.']},
#    {'questions': ' is the video footage from 2022?',
#     'top_k_doc': ['19068 year 2022 stock video clips in 4k and hd for creative projects. plus, explore over 11 million high-quality video and footage clips in every category.']}],
#   'label': 'False'},
#  {'claim': 'Photo shows Imran Khan supporter waving gun during rally in 2023',
#   'evidences': [{'questions': 'is there a photo showing an imran khan supporter waving a gun during a rally in 2023?\n',
#     'top_k_doc': ['nov 10, 2022  ... pistol and started shooting while khan waved at his supporters at the event last week. in the video address, khan rejected the police version.']},
#    {'questions': ' is the photo authentic and not manipulated or edited?\n',
#     'top_k_doc': ['26 mag 2023  the given correct answer is "real." this suggests that the photo in question is authentic and not manipulated or altered in any way. rate this ...']},
#    {'questions': ' did the incident of an imran khan supporter waving a gun during a rally in 2023 actually happen?',
#     'top_k_doc': ['nov 10, 2022  ... pistol and started shooting while khan waved at his supporters at the event last week. in the video address, khan rejected the police version.']}],
#   'label': 'Half True/False'},
#  {'claim': 'Hindu population has fallen by 19% in Assam and Muslim population increased by 21%',
#   'evidences': [{'questions': 'has the hindu population in assam decreased by 19%?\n',
#     'top_k_doc': ['1 gen 2018  hindu percentage in assam have decreased from 100% in. continue ... west bengal has a muslim population of 27% and hindu population of 70% .']},
#    {'questions': ' has the muslim population in assam increased by 21%?\n',
#     'top_k_doc': ["2018-01-16  he concludes that assam's muslim population has increased because of ... it shows that districts with a growth rate of 21% and above also have a ..."]},
#    {'questions': ' is there evidence to support the claim that the hindu population has fallen and the muslim population has increased in assam?',
#     'top_k_doc': ['feb 3, 2022  the latest figures demonstrate that the proportionate growth of the muslim population in assam, in comparison with other religious communities, ...']}],
#   'label': 'False'},
#  {'claim': 'A patent for coronavirus was granted in 2018 to the Pirbright Institute UK, founded by Bill and Melinda Gates.',
#   'evidences': [{'questions': 'was a patent for coronavirus granted in 2018?\n',
#     'top_k_doc': ['unitary patent. start of new system expected in 2022. stay informed  coronavirus (covid-19). continually updated information for customers']},
#    {'questions': ' was the patent granted to the pirbright institute uk?\n',
#     'top_k_doc': ['patent submission that predates the one already granted.53 this has raised pirbright institute. . professor charles godfray, department of zoology']},
#    {'questions': ' was the pirbright institute uk founded by bill and melinda gates?',
#     'top_k_doc': ['by krw matthews  2008  cited by 32  most notable of these foundations has been the bill & melinda gates foundation (bmgf; seattle, wa, usa; www.gatesfoundation.org), which was set up by the couple ...']}],
#   'label': 'False'},
#  {'claim': 'because the photo comes from a blog post published in September 2022.',
#   'evidences': [{'questions': 'is the photo in question from a blog post published in september 2022?\n',
#     'top_k_doc': ['may 26, 2023  the given correct answer is "real." this suggests that the photo in question is authentic and not manipulated or altered in any way. 2.']},
#    {'questions': ' is the photo authentic and not digitally manipulated?\n',
#     'top_k_doc': ['26 mag 2023  the given correct answer is "real." this suggests that the photo in question is authentic and not manipulated or altered in any way. rate this ...']},
#    {'questions': ' is there any evidence to suggest that the photo is fake or misleading?',
#     'top_k_doc': ['an image has been manipulated, but precisely what about it is fake. evidence that people can use to determine if a photo has been manipulated.']}],
#   'label': 'False'},
#  {'claim': '"We\'ve got 7.2 percent unemployment (in Ohio), but when you include the folks who have stopped looking for work, it\'s actually over 10 percent."',
#   'evidences': [{'questions': 'is the official unemployment rate in ohio 7.2 percent?\n',
#     'top_k_doc': ["ohio's unemployment rate was 7.2 percent in june, down from 7.3 percent in may, according to data released this morning by the ohio department of job and ..."]},
#    {'questions': ' are there people in ohio who have stopped looking for work?\n',
#     'top_k_doc': ["... people who have stopped looking for work because they can't find a job. is this true? yes and no. there are six unemployment rates calculated, and each one ..."]},
#    {'questions': ' does the official unemployment rate in ohio not account for those who have stopped looking for work?',
#     'top_k_doc': ['national unemployment rate  state & local unemployment rates  unemployment ohio includes the following metropolitan areas for which an economy at a glance']}],
#   'label': 'Half True/False'},
#  {'claim': '"Up [to] 20% of high school learners have tried to take their own lives."',
#   'evidences': [{'questions': 'is the suicide rate among high school learners significantly higher than the general population?\n',
#     'top_k_doc': ['the suicide attempt rate for high school students differs between males and ... the rate among other students was highly variable but increased overall by 14.1.293 pagine']},
#    {'questions': ' is there evidence to support the claim that up to 20% of high school learners have attempted suicide?\n',
#     'top_k_doc': ['jun 13, 2023  data shows that a significant number of high school students have seriously considered suicide or attempted it, says dr. thordarson. the ...']},
#    {'questions': ' are there any factors contributing to the high suicide rate among high school learners?',
#     'top_k_doc': ['of high school students reported a suicide attempt in the past year.3 rates among high school students - 19 states and large urban school districts, 2017']}],
#   'label': 'Half True/False'},
#  {'claim': 'A video that went viral in July 2023 authentically depicted an ad in Japan that read "Stop Zelenskyy, Stop War."',
#   'evidences': [{'questions': 'was there a video that went viral in july 2023?\n',
#     'top_k_doc': ['5 giorni fa  the video was shared with an array of claims, ranging from the dead ... for example, a video went viral in march 2022 allegedly showing ...']},
#    {'questions': ' did the video depict an ad in japan?\n',
#     'top_k_doc': ["2 ago 2023  is this an authentic ad in japan reading, 'stop zelenskyy, stop war'? 3 months ago. www.snopes.com  does this photo show a real giant among men ..."]},
#    {'questions': ' did the ad in the video read "stop zelenskyy, stop war"?',
#     'top_k_doc': ['video was shot in october 2020, and the advertisement on the banner has nothing ... was the banner stop zelenskyy, stop war placed in japan? on july 31 and ...']}],
#   'label': 'False'},
#  {'claim': 'Every illegal immigrant "can be eligible for up to $36,000 to $38,000 in earned income tax credits without paying a dime in."',
#   'evidences': [{'questions': 'is every illegal immigrant eligible for earned income tax credits?\n',
#     'top_k_doc': ['many undocumented immigrants also pay state income taxes. the best earned income tax credit eligibility: post-reform, the study assumes']},
#    {'questions': ' can illegal immigrants receive up to $36,000 to $38,000 in earned income tax credits?\n',
#     'top_k_doc': ['2015-08-22  indeed, the annual cost of free tax credits alone paid to illegal immigrants quadrupled to $4.2 billion in 2011. the effects on jobseekers ...']},
#    {'questions': ' do illegal immigrants receive earned income tax credits without paying anything?',
#     'top_k_doc': ["2015-10-01  indeed, the annual cost of free tax credits alone paid to illegal immigrants quadrupled to $4.2 billion in 2011. have 'free tax credits ..."]}],
#   'label': 'False'},
#  {'claim': 'A scam is asking people to input the personal details, including bank details, to receive "Covid-19 Relieve."',
#   'evidences': [{'questions': 'is there a scam asking people to input personal details to receive "covid-19 relief"?\n',
#     'top_k_doc': ['it is a scam that asks people to input personal details, including bank details, to receive covid-19 relieve the fact it says relieve when it should say...']},
#    {'questions': ' are people being asked to provide their bank details to receive "covid-19 relief"?\n',
#     'top_k_doc': ['those funds at the increased federal share for covid-19 response. covid-19 to request temporary relief from federal requirements under 49']},
#    {'questions': ' is the "covid-19 relief" being offered a legitimate program?',
#     'top_k_doc': ['those funds at the increased federal share for covid-19 response. covid-19 to request temporary relief from federal requirements under 49']}],
#   'label': 'True'},
#  {'claim': 'Confusion spreads online about 15,000 people detained in Iran',
#   'evidences': [{'questions': 'is there confusion spreading online about 15,000 people being detained in iran?\n',
#     'top_k_doc': ['fact check-confusion spreads online about 15,000 people detained in iran iran has detained two spanish nationals during anti-government protests  read more']},
#    {'questions': ' are there 15,000 people currently detained in iran?\n',
#     'top_k_doc': ['in february, iran had acknowledged tens of thousands had been detained in the protests. mondays acknowledgment from ejehi offered an even higher than what activists had previously cited. however, theres been no mass release of prisoners documented in recent days by iranian media reports or activists. more than 19,700 people have been arrested during the protests, according to human rights activists in iran, a group thats been tracking the crackdown. at least 530 people have been killed as authorities violently suppressed demonstrations, the group said. iran has not offered a death toll for months. dubai, united arab emirates (ap)  iran announced monday that the countrys supreme leader has pardoned more than 22,000 people arrested in the recent anti-government protests that swept the islamic republic. there was no immediate independent confirmation of the mass release.']},
#    {'questions': ' is the claim about 15,000 people being detained in iran accurate?',
#     'top_k_doc': ['in february, iran had acknowledged tens of thousands had been detained in the protests. mondays acknowledgment from ejehi offered an even higher than what activists had previously cited. however, theres been no mass release of prisoners documented in recent days by iranian media reports or activists. more than 19,700 people have been arrested during the protests, according to human rights activists in iran, a group thats been tracking the crackdown. at least 530 people have been killed as authorities violently suppressed demonstrations, the group said. iran has not offered a death toll for months. dubai, united arab emirates (ap)  iran announced monday that the countrys supreme leader has pardoned more than 22,000 people arrested in the recent anti-government protests that swept the islamic republic. there was no immediate independent confirmation of the mass release.']}],
#   'label': 'False'},
#  {'claim': '"For several days in July of 2012, Greenland surface ice cover melted more than at any time in 30 years of satellite observation. During that month, an estimated 97% of the ice sheet thawed."',
#   'evidences': [{'questions': 'did the surface ice cover in greenland melt more in july 2012 than in any other month in the past 30 years?\n',
#     'top_k_doc': ["24 lug 2012  for days this month, greenland's surface ice cover melted over a larger area than at any time in more than 30 years of satellite ..."]},
#    {'questions': ' was there an estimated 97% of the ice sheet that thawed during july 2012?\n',
#     'top_k_doc': ['jul 24, 2012  according to satellite data, an estimated 97 percent of the ice sheet surface thawed at some point in mid-july. 97 percent. usually about ...']},
#    {'questions': ' did satellite observations confirm the increased melting of the surface ice cover in greenland in july 2012?',
#     'top_k_doc': ['cituojant sv nghiem  2012  cituoja 528  satellite observations reveal that melt occurred at or near the surface of the greenland ice sheet across 98.6% of its entire extent on 12 july ...']}],
#   'label': 'Half True/False'},
#  {'claim': '"Close to 40% of South Africans who need jobs are unemployed, meaning that more than nine million South Africans who need jobs and are capable of working cannot find employment."',
#   'evidences': [{'questions': 'is the unemployment rate in south africa close to 40%?\n',
#     'top_k_doc': ["2022-04-29  south africa's unemployment rate is heading to 40% ... south africa is expected to generate almost two million jobs by 2030  but this is not near ..."]},
#    {'questions': ' are there more than nine million south africans who need jobs and are capable of working?\n',
#     'top_k_doc': ['9 nov 2020  millions of south africans who need jobs and are capable of working cannot find employment ... south africa has more than enough jobs but']},
#    {'questions': ' are the unemployed south africans unable to find employment?',
#     'top_k_doc': ["close to 40% of south africans who need jobs are unemployed, meaning that more than nine million south africans who need jobs and are capable of working cannot find employment. that's why..."]}],
#   'label': 'True'},
#  {'claim': 'CLAIM:A new autopsy report for George Floyd has been released in 2023, revealing he died from a drug overdose,not from the actions of arresting Minneapolis police officers.',
#   'evidences': [{'questions': 'is there a new autopsy report for george floyd released in 2023?\n',
#     'top_k_doc': ['george floyd autopsy. original document (pdf) . contributed by click houston (kprc 2). document, plain text, thumbnail, search results. 20 1 of 20.']},
#    {'questions': ' does the new autopsy report for george floyd reveal that he died from a drug overdose?\n',
#     'top_k_doc': ['14 avr. 2021  floyd died of an overdose because of the relatively high levels of fentanyl found in his blood collected at the hospital. instead ...']},
#    {'questions': ' does the new autopsy report contradict the previous findings that george floyd died from the actions of arresting minneapolis police officers?',
#     'top_k_doc': ['do the autopsies of george floyd agree, or not? news reports from last week suggest the report produced by the hennepin county medical examiner and the one produced by an examiner hired by floyds family disagreed on his cause of death. the county ruled the cause to be cardiopulmonary arrest complicating law enforcement subdual, restraint, and neck compression. it also cited heart disease and drug use as factors that could have contributed to the death. the secondary autopsy, by contrast, specifically said floyd died from asphyxia. the hennepin county autopsy may have mentioned factors beyond police conduct, but it was really just saying floyds heart stopped while police were restraining him and pressing on his neck, said melinek, carter and dr. michael freeman, professor of forensic medicine and epidemiology at maastricht university in the netherlands. its not a claim that he died of a heart attack, drugs, or pre-existing conditions, they told me. the cause of death is police restraint, melinek said, just like in the autopsy floyds family commissioned. that is both a misunderstanding of the report and an example of the difficulty in identifying cause of death, experts said. its a misunderstanding because an earlier legal document, put out to explain the charges against the officer who kneeled on floyd, said the county had found no injuries consistent with asphyxia caused by physical trauma. but the actual autopsy report doesnt mention the word asphyxia at all. it does, however, describe neck compression as a direct cause of floyds death  meaning the blood flow (and, thus, oxygen) to floyds brain and heart were cut off. it doesnt take physical trauma to asphyxiate someone.']}],
#   'label': 'False'},
#  {'claim': 'Two pipeline workers were given fentanyl-laced water bottles in Chicago suburbs',
#   'evidences': [{'questions': 'were two pipeline workers given water bottles laced with fentanyl in the chicago suburbs?\n',
#     'top_k_doc': ['2023-07-26  the claim: two pipeline workers were given fentanyl-laced water bottles in chicago suburbs  our rating: false  company denied its workers were ...']},
#    {'questions': ' is there evidence to support the claim that two pipeline workers were given fentanyl-laced water bottles?\n',
#     'top_k_doc': ['2023-07-26  the claim: two pipeline workers were given fentanyl-laced water bottles in chicago suburbs  our rating: false  company denied its workers were ...']},
#    {'questions': ' did the incident of two pipeline workers being given fentanyl-laced water bottles occur in the chicago suburbs?',
#     'top_k_doc': ['2023-07-26  the claim: two pipeline workers were given fentanyl-laced water bottles in chicago suburbs  our rating: false  company denied its workers were ...']}],
#   'label': 'False'},
#  {'claim': 'Warum in Berlin plötzlich 200.000 Ausländer mehr leben/n„Jeder vierte Berliner ist ein Ausländer” titelt die Berliner Zeitung „B.Z.”. Woher kommen 200.000 ausländische Neu-Berliner in nur einem Jahr?',
#   'evidences': [{'questions': 'are there 200,000 more foreigners living in berlin compared to the previous year?\n',
#     'top_k_doc': ['25 mai 2023  germany: nearly 300 gang rapes recorded in berlin since 2020, and more than half were committed by foreigners. across europe, migrants are ...']},
#    {'questions': ' is it true that one in four residents of berlin is a foreigner?\n',
#     'top_k_doc': ["in 2015, more than 1 million migrants, many of them syrians escaping their country's civil war, traveled across the mediterranean and europe to reach germany, according to german officials. afghan brothers ahmad and ikram, who did not want to give their real names, arrived in germany in 2015 as part of the wave of migrants seeking a new life in europe. they are currently staging a protest outside the foreign ministry in berlin, to demand that germany speed up the asylum process for refugees. so, could germany face another migrant influx? the situation is very different, says nora brezger of the berlin refugee council, a support group for migrants."]},
#    {'questions': ' did the berliner zeitung "b.z." report that 200,000 foreigners have moved to berlin in just one year?',
# ...
#   'evidences': [{'questions': 'are the jan. 6 defendants being held in prison? \n',
#     'top_k_doc': ['lake said defendants were being held in "prison" without being charged, but defendants are held pre-trial in jails. the majority of defendants awaiting trial have been released from jail pending the outcome of their case. the number of defendants detained pretrial is between 75 and 85 at any given time, according to the u.s. attorney\'s office. lake said jan. 6 defendants "are being held in prison without being charged." lake did not cite any particular defendants during her interview, and her campaign didnt respond to our request for evidence.']},
#    {'questions': ' have the jan. 6 defendants been charged with a crime? \n',
#     'top_k_doc': ['6 juil. 2023  approximately 935 defendants have been charged with entering or remaining in a restricted federal building or grounds. ... federal charges, many ...']},
#    {'questions': ' is there evidence to support the claim that the jan. 6 defendants are being held in prison without being charged?',
#     'top_k_doc': ['defendants may confront and question witnesses and present witnesses and evidence on their own behalf. ... there was little evidence to support those charges. as ...']}],
#   'label': 'False'},
#  {'claim': 'In einem Video sagt ein Landwirt, sein geernteter Weizen habe einen Proteingehalt von 8,8 Prozent. Das sei zu niedrig, um damit Brot zu backen. Schuld daran sei die Düngeverordnung.',
#   'evidences': [{'questions': 'hat der landwirt behauptet, dass sein geernteter weizen einen proteingehalt von 8,8 prozent hat?\n',
#     'top_k_doc': ['es bestand ein weitgehender konsens im plenum, dass mit der priorisierung des proteingehaltes in der erfassung ein luxusproblem entstanden ist: ein groer anteil der inlndischen verwertung auch von qualittssorten erfolgt in der futtermittelindustrie. moderne weizensorten erzielen gute backeigenschaften auch mit niedrigem proteingehalt. diese aspekte unterstreichen, dass es notwendig ist, die heute geforderten proteingehalte abzusenken, um den stickstoffeinsatz in der weizenproduktion zuknftig weiter reduzieren zu knnen. seit der novellierung der dngeverordnung (dv) 2017 wird in fachkreisen darber diskutiert, ob durch die neuen vorgaben in der dngeverordnung negative auswirkungen auf den proteingehalt und damit auf die backqualitt des weizens zu erwarten sind. ergebnisse aus mehrjhrigen versuchen an unterschiedlichen standorten deuten an, dass befrchtungen ber einen dramatischen rckgang der proteingehalte zurzeit unbegrndet sind. fr e-qualittsweizen sind die laut dv mglichen dngergaben weiterhin auf einem ausreichenden niveau, um qualitativ hochwertigen weizen zu erzeugen. auf der anderen seite wird jedoch ohne anpassungsmanahmen im dngungsregime von einem rckgang der mittleren rohproteingehalte von backweizen im bereich von 0,2 bis 0,3 prozent auszugehen sein. dieser abfall wird bei hohen ertrgen (hochertragsjahre, hochertragsregionen) hher sein als bei mittlerem ertragsniveau.']},
#    {'questions': ' hat der landwirt gesagt, dass ein proteingehalt von 8,8 prozent zu niedrig ist, um brot zu backen?\n',
#     'top_k_doc': ['ab wie viel eiwei/protein zhlt ein mehl als backstark? das ist schwer zu beantworten, da der w-wert hier entscheidend ist. typische mehle in deutschland haben 10-12g proteingehalt (z.b. weizenmehl typ 405 oder 550; dinkelmehl typ 630). diese mehle gehren eher zu den mehlen mit geringer oder max. mittlerer backstrke. ab 13g eiwei kommt man in den bereich der backstrkeren mehle. so ist das eiwei/protein auf mehl im handel zu erkennen:']},
#    {'questions': ' hat der landwirt die düngeverordnung für den niedrigen proteingehalt verantwortlich gemacht?',
#     'top_k_doc': ['dec 29, 2019  das brotgetreide wird den landwirten nach proteingehalt bezahlt. je hher der proteingehalt im getreide, desto mehr geld gibt es dafr. 12 % ist ...']}],
#   'label': 'False'},
#  {'claim': 'The FBI discovered a mysterious photograph behind a dumpster in 1982 whichshoweda man in a bunny mask dragging a woman into a building.',
#   'evidences': [{'questions': 'did the fbi discover a photograph behind a dumpster in 1982?\n',
#     'top_k_doc': ['in 1982, this photograph was found in a dumpster behind a restaurant in georgia. the fbi examined it and found.']},
#    {'questions': ' was the photograph discovered by the fbi mysterious?\n',
#     'top_k_doc': ['legend: "the fbi discovered a mysterious photograph behind a dumpster in 1982 which showed a man in a bunny mask dragging a woman into a building."']},
#    {'questions': ' did the photograph show a man in a bunny mask dragging a woman into a building?',
#     'top_k_doc': ['20 sept. 2019  contrary to popular belief, the photograph of a man in a bunny mask dragging a woman into a building is a piece of art, not a piece of evidence.']}],
#   'label': 'False'},
#  {'claim': '“We created more new jobs in two years than any president did in their entire term.”',
#   'evidences': [{'questions': 'did the current president create more new jobs in two years than any previous president did in their entire term?\n',
#     'top_k_doc': ['jobs created in two years than any president has ever created in four years. in any four years than my predecessor. nearly 25% of the entire']},
#    {'questions': ' did any previous president create more new jobs in their entire term than the current president did in two years?\n',
#     'top_k_doc': ['jobs created in two years than any president has ever created in four years. in any four years than my predecessor. nearly 25% of the entire']},
#    {'questions': ' is there evidence to support the claim that the current president created more new jobs in two years than any previous president did in their entire term?',
#     'top_k_doc': ['jobs created in two years than any president has ever created in four years. in any four years than my predecessor. nearly 25% of the entire']}],
#   'label': 'Half True/False'},
#  {'claim': '"When the Covid pandemic hit our country, we had an ICU bed capacity of only 180 beds countrywide ... We increased the ICU bed capacity by 502% during the Covid period."',
#   'evidences': [{'questions': 'did the icu bed capacity in the country increase during the covid pandemic?\n',
#     'top_k_doc': ['discussion these findings suggest that icu bed use is an important indicator, but not the sole contributing factor, of stress to health care and public health sectors, with excess deaths emerging in the weeks after a surge in covid-19 hospitalizations. the results of this study support a larger body of evidence from previous cisa analyses of the potential consequences of the covid-19 pandemic on cisa provide medical care national critical functions, and the cascading effects on the essential critical infrastructure workforce (7). even before covid-19s emergence, emergency department crowding, icu capacity, and ambulance diversion were reported to have adverse outcomes, such as increased medical errors and reduced quality of care (8) as well as delays in treatment, medication error, longer patient stays, poorer outcomes, and increased mortality (9). during 2020, the impact of these effects, which included potentially avoidable excess deaths, fell more heavily on working-aged adults from marginalized communities who experience poor access to health care outside pandemic conditions (10). for example, racial and ethnic subgroups experienced disproportionately higher percentage increases in deaths, with the most pronounced effect among the hispanic/latino communities who represent an estimated 21% of the essential critical infrastructure workforce. the nonlinear nature of the curve (figure) shows how these negative effects increase exponentially as the system becomes more stressed. as of october 25, 2021, per data from the hhs timeseries dataset, capacity in adult icus nationwide has exceeded 75% for at least 12 weeks. this means that the united states continues to experience the high and sustained levels of hospital strain that, according to the models results, are associated with significant subsequent increases in excess deaths. the findings in this report are subject to at least three limitations. first, modeling studies are subject to uncertainty, including unforeseen events that could cause deviations from the modeled scenarios. second, data were incomplete because of the lag in time between when deaths occurred and when death certificates were completed and processed. finally, although pandemic-driven icu bed occupancy is not a direct cause of excess deaths, high icu capacity is a marker of broader issues that can contribute to excess deaths, such as curtailed services, stressed operations, and public reluctance to seek services. additional research is warranted to assess the cascading effects of the degraded and disrupted functioning of the health care sector, especially during covid-19 surges. studying the nature and extent of these stresses on critical infrastructure and essential critical infrastructure workers**** can help elucidate the consequences of the pandemic and potential ways to address health system vulnerabilities to ensure improved resilience in the future. this analysis indicates the importance of controlling case growth and the subsequent need for hospitalizations before severe strain. state, local, tribal, and territorial leaders could evaluate ways to reduce strain on public health and health care infrastructures, including implementing interventions to reduce overall disease prevalence such as vaccination and other prevention strategies, as well as ways to expand or enhance capacity during times of high disease prevalence.']},
#    {'questions': ' was the initial icu bed capacity in the country only 180 beds?\n',
#     'top_k_doc': ['dec 24, 2020  ... (icu) beds available across the country, and many were completely full. ... covid-19 patients were at more than 95 percent icu bed capacity. in ...']},
#    {'questions': ' did the country increase its icu bed capacity by 502% during the covid period?',
#     'top_k_doc': ['dec 24, 2020  ... (icu) beds available across the country, and many were completely full. ... covid-19 patients were at more than 95 percent icu bed capacity. in ...']}],
#   'label': 'False'},
#  {'claim': 'The five states that outlaw collective bargaining for teachers all rank below 44th in the nation in test scores, while Wisconsin ranks 2nd.',
#   'evidences': [{'questions': 'do the five states that outlaw collective bargaining for teachers rank below 44th in the nation in test scores?\n',
#     'top_k_doc': ['only five states do not allow collective bargaining for educators, effectively banning teachers unions. those states and their sat/act rankings are as follows:']},
#    {'questions': ' does wisconsin rank 2nd in the nation in test scores?\n',
#     'top_k_doc': ["24 oct. 2022  at the same time, wisconsin scores statewide climbed in the rankings. though the state's 2022 scores declined since the last national assessment ..."]},
#    {'questions': ' is there a correlation between outlawing collective bargaining for teachers and lower test scores?',
#     'top_k_doc': ['only five states do not allow collective bargaining for educators, effectively banning teachers unions. those states and their sat/act rankings are as follows:']}],
#   'label': 'False'},
#  {'claim': 'Video shows Joe Biden waved to nobody after a July 2023 speech in Lithuania',
#   'evidences': [{'questions': 'did joe biden give a speech in lithuania in july 2023?\n',
#     'top_k_doc': ["13 juil. 2023  fact check: biden did not wave 'to nobody' after his speech in lithuania -- audience included... 3 views  2 months ago ...more ..."]},
#    {'questions': ' was there a video showing joe biden waving to nobody after the speech?\n',
#     'top_k_doc': ['joe biden is being called out by social media users today as a video appears to show him waving to an empty field as he gets off his plane. but was he actually waving at no one? a video has gone viral online that seemingly shows us democratic presidential candidate joe biden waving at nobody.']},
#    {'questions': ' is there evidence to support the claim that joe biden waved to nobody after the speech in lithuania?',
#     'top_k_doc': ["13 juil. 2023  fact check: biden did not wave 'to nobody' after his speech in lithuania -- audience included... 3 views  2 months ago ...more ..."]}],
#   'label': 'False'},
#  {'claim': "A WhatsApp video called 'India is doing it' will hack the phone in 10 seconds.",
#   'evidences': [{'questions': "is there a video called 'india is doing it' circulating on whatsapp?\n",
#     'top_k_doc': ['some users are receiving messages about a video called "argentina is doing it". it added: "given that no evidence shows that the \'argentina is doing it\' video exists, nor that it is part of a malware scheme to hack cell phones  as well as the similarities in language between this viral message and previous whatsapp hoaxes  we rate this claim \'false\'."']},
#    {'questions': ' can a video hack a phone in 10 seconds?\n',
#     'top_k_doc': ["22 ott 2020  the message regarding a supposed video, called 'india is doing it', claims that it will hack your phone in 10 seconds if you watch it and cannot ..."]},
#    {'questions': " is there evidence that the 'india is doing it' video is capable of hacking phones?",
#     'top_k_doc': ['the message regards a supposed video called india is doing it and claims it will hack your phone in 10 seconds if you watch it.']}],
#   'label': 'False'},
#  {'claim': 'A photograph shows the offspring of a woman who gave birth to 69 children.',
#   'evidences': [{'questions': 'is the photograph authentic?\n',
#     'top_k_doc': ['authenticity and manipulation in the realm of photography.']},
#    {'questions': ' is it possible for a woman to give birth to 69 children?\n',
#     'top_k_doc': ['there is no all-purpose answer as it largely depends on the individual woman and her overall health and fertility. however, there are several documented cases of women giving birth to large numbers of babies over the course of their lifetimes. there is no straightforward answer to this question as it depends on a number of factors, including the health of the mother and her age. however, it is generally accepted that a woman can give birth to around 20-30 babies in her lifetime. this number may seem high, but it is important to remember that many women miscarry or have stillbirths, which reduces the overall number of live births. additionally, some women choose to have multiple abortions, which also contributes to a lower total number of live births. so what is the record for the most babies a woman has given birth to? it seems that it largely depends on who you ask!']},
#    {'questions': ' is there any evidence to support the claim that the woman in the photograph gave birth to 69 children?',
#     'top_k_doc': ['21 oct. 2015  conceiving and raising one child is demanding enough  yet historical reports suggest that one woman bore 69. are they true? and will modern ...']}],
#   'label': 'Half True/False'},
#  {'claim': '"We\'ve got some 37-million of our fellow citizens who are living in poverty; about 12-million or 13-million are children."',
#   'evidences': [{'questions': 'is the poverty rate in the united states high?\n',
#     'top_k_doc': ['income poverty rates are very high  around. 20% of children in the u.s. live in how the united states compares to other oecd countries on 20 key measures.']},
#    {'questions': ' are there approximately 37 million people living in poverty in the united states?\n',
#     'top_k_doc': ['in 2020, 37 million people lived in poverty usa. that means the poverty rate for 2020 was 11.4%.']},
#    {'questions': ' are there approximately 12-13 million children living in poverty in the united states?',
#     'top_k_doc': ['2022-10-26  according to the national center for children in poverty, over 11 million kids in the united states live below the federal poverty line. that ...']}],
#   'label': 'True'},
#  ...]

# %% [markdown]
# TODO:
# * Experiment with bm25s to make it faster and also work with the stemmer for numbers - https://github.com/xhluca/bm25s
# * Refactor the custom tokenizer for BM25 here and verify how good it is.
# * Follow up on https://huggingface.co/learn/nlp-course/en/chapter2/4?fw=pt#tokenizers and https://huggingface.co/spaces/huggingface/number-tokenization-blog
# * Investigate what else in terms of tokenization/adaptation for BM25 can be done already at this step? (keepign in mind this first step is a word based tokenizer)

# %% [markdown]
# # PART 1: BM25 RETRIEVAL

# %% [markdown]
# The goal of the following tokenizer function is to introduce some normalizations - e.g. for covid, for numbers, for dates, for crore, such that we aid BM25 into recognizing simlarities in the words.
#
# Numbers in BM25
#
#     Tokenization:
#         When tokenizing text, numbers are typically split based on spaces or punctuation, just like words. For example:
#             "In 2023, 10% of users" → Tokens: ["In", "2023", "10", "of", "users"].
#         Each number is treated as an independent token, similar to a word.
#
#     Scoring:
#         BM25 assigns a term frequency (TF) and inverse document frequency (IDF) to numbers just like it does to any other word.
#         If a number (e.g., "2023") appears frequently in both the query and the document, it will contribute to the document's relevance score.
#
#     Implications:
#         Numbers in claims and evidence (e.g., "86,000" or "5%") are matched based on their exact representation.
#         BM25 does not understand numerical relationships or semantic context. For example:
#             It cannot recognize that "10%" is similar to "0.1" or "10 percent".
#             It does not reason about magnitudes or intervals (e.g., "86,000" vs. "85,000").
#
# Limitations of Treating Numbers as Words
#
#     Exact Match Dependency:
#         If the number format in the query does not exactly match the format in the document (e.g., "10%" vs. "10 percent"), BM25 will not treat them as equivalent.
#
#     No Numerical Reasoning:
#         BM25 cannot interpret numerical relations like comparisons ("greater than", "equal to") or ranges ("10-20").
#
#     Potential for Noise:
#         Numbers that are irrelevant to the query might still appear frequently in documents, leading to noise in retrieval.

# %% [markdown]
# Load evidence corpus

# %%
with open("../../data/corpus_evidence_unified.json") as f:
  corpus = json.load(f)

# %% [markdown]
# Load claim corpus

# %%
with open("../../data/English/train_claims_quantemp.json") as f:
  train_data = json.load(f)

with open("../../data/English/val_claims_quantemp.json") as f:
  val_data = json.load(f)

# %%
all_claims = []
all_synthetic_questions = []

for claim_id, claim in enumerate(train_data):
    all_claims.append((claim_id, claim['claim']))
    for question_id, j in enumerate(claim['evidences']):
        all_synthetic_questions.append(((claim_id, question_id), j['questions']))

# %%
 def preprocess_corpus(evidence_dict):
    # Convert dict of documents to a list
    evidence_list = list(evidence_dict.values())

    # Parallel tokenization
    tokenized_corpus = Parallel(n_jobs=-1)(
        delayed(tokenizer)(doc, claim_id) for claim_id, doc in enumerate(evidence_list)
    )
 
    return tokenized_corpus

# %%
def preprocess_queries(queries_data):
    # Parallel tokenization
    tokenized_corpus = Parallel(n_jobs=-1)(
        delayed(tokenizer)(doc, claim_question_id) for claim_question_id, doc in queries_data
    )
    return tokenized_corpus

# %%
tokenized_queries = preprocess_queries(all_synthetic_questions)

# %%
tokenized_evidence = preprocess_corpus(corpus)

# %%
# # Are all of them split in 3 questions? probably not - verify that
# train_data

# %%
# Function to process a single query, return back indices and scores
def process_query(query_tokens, id, top_k=100):
    global bm25
    scores = bm25.get_scores(query_tokens)
    top_indices = np.argsort(scores)[::-1][:top_k]  # Get top-k indices
    top_scores = np.sort(scores)[::-1][:top_k]
    return (id, top_indices, top_scores)

# %%
# Initialize BM25
def init_bm25(evidence_corpus):
    global bm25
    bm25 = BM25Okapi(evidence_corpus)

# %%
evidence_corpus = [j for x, j in tokenized_evidence]
init_bm25(evidence_corpus)

# %%
 # Process All queries in parallel
results = Parallel(n_jobs=-1, backend="multiprocessing")(
        delayed(process_query)(query, id) for id, query in tokenized_queries
    )

# %%
import pickle

# Save an object to a file
def save_pickle(obj, filename):
    """
    Save a Python object to a file using pickle.
    
    Args:
        obj: The Python object to save.
        filename: The name of the file where the object will be saved.
    """
    with open(filename, 'wb') as f:
        pickle.dump(obj, f)

# Example usage
data = {'key': 'value', 'numbers': [1, 2, 3, 4, 5]}
save_pickle(results, '../../output/bm25-1st-step-evidence.pkl')
save_pickle(tokenized_queries, '../../output/tokenized_queries.pkl')

# %% [markdown]
# # PART 2: SEMANTIC RERANKING WITH TRANSFORMERS

# %%
# Given the corpus above, how can we re-rank?
# https://huggingface.co/models?search=modernbert
# https://huggingface.co/models?pipeline_tag=sentence-similarity&sort=trending&search=modernbert
# So here for this step we can possibly re-learn things or?

# %%
import pickle

with open('../../output/bm25-1st-step-evidence.pkl', 'rb') as file: 
      
    # Call load method to deserialze 
    results = pickle.load(file)

# %%
all_synthetic_questions[1]

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("tasksource/ModernBERT-base-embed")
# Try here the tokenization steps that are in the other paper with the numerical reasoning things
# Add the scientific notation too, maybe? Or at least some other normalization step
# Alternative with the nomics as it is a smaller model, might be easier for you to rerank
# Maybe we can finetune the model on FinQA (and similar) using hte tokenizer that is suggested in the other dataset
# It would be interesting to see how much correlation is there between BM25 and this stuff btw.
# Need a different workaround here, that does not consume much CUDA memory and you can rerun everything without blowing up the memory.


# Load the tokenizer and model


# # Encode a single sentence
# def encode(text):
#     tokens = tokenizer(text, return_tensors="pt", padding=True)
#     with torch.no_grad():
#         output = model(**tokens)
#         embeddings = output.last_hidden_state.mean(dim=1)  # Mean pooling
#     return embeddings

for evidence in all_corpus[results[0][1]]:
    query = model.encode(all_synthetic_questions[0])
    against = model.encode(evidence)
    print(model.similarity(query,against))

# %%
all_corpus[results[0][1]]

# %%
# Compute similarity
query_embedding = encode(all_synthetic_questions[0][1])
doc_embeddings = torch.stack([encode(doc) for doc in all_corpus[results[0][1]]])  # Batch encode documents
cosine_similarities = torch.nn.functional.cosine_similarity(query_embedding, doc_embeddings)

# %%
cosine_similarities

# %%
# Tokenize all inputs and get lengths
input_lengths = [len(tokenizer(text)['input_ids']) for text in dataset]

# Analyze distribution
import numpy as np
print(f"Max input length: {max(input_lengths)}")
print(f"90th percentile input length: {np.percentile(input_lengths, 90)}")
